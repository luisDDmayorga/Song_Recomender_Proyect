# %% [markdown]
# # Importing libraries

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials
import getpass
import pandas as pd
from unidecode import unidecode
from tqdm.notebook import tqdm

# %% [markdown]
# # Credentials

# %%
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
sp=spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,client_secret=client_secret))

# %% [markdown]
# # Playlists

# %%
# in case we need it after for a playlist with more than 100 songs
def get_playlist_tracks(user_id,playlist_id):
    results=sp.user_playlist_tracks(user_id,playlist_id)
    tracks=results["items"]
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# ## Hiphop Playlist

# %% [markdown]
# - **user name:** "Eric Peelen"
# - **playlist id:** "2K31J2EjcYhKEDCh7Flli1"

# %%
results2=get_playlist_tracks("Eric Peelen","2K31J2EjcYhKEDCh7Flli1")

# %%
len(results2)
# Out:
# 930

# %%
song_name=[]
song_ID=[]
song_artist=[]
playlist=results2

# %%
for r in results2: 
    song_ID.append(r["track"]["id"])

# %%
for r in results2: 
    song_name.append(r["track"]["name"])

# %%
for r in results2: 
    song_artist.append(r["track"]["artists"][0]["name"])

# %%
import pandas as pd

# %%
playlist_song_info=pd.DataFrame({"song_name":song_name,"song_ID":song_ID,"song_artist":song_artist})

# %%
playlist_song_info
# Out:
#                                     song_name                 song_ID  \
# 0          Sing About Me, I'm Dying Of Thirst  1Z2FvDFZSDQ23s4BDqpWqZ
# 1                                     Yonkers  4OKXvqtfwlvY2fYJ2lzHPH
# 2                                Angel Duster  0VLYOGNIaiOxEHKWOctcA4
# 3                           Rhymes Like Dimes  12OkZyDWNBLUqoReoseGrc
# 4                             The Last to Say  4O7P2Rug3l4IySk0TEx4Xe
# ..                                        ...                     ...
# 925                           Dead Presidents  4sLFhYeZOLJ3G7XmVilAtr
# 926                      Dead President Heads  7FUud32IMLTIwb1i5AOUNY
# 927  Last Day (feat. The Lox) - 2014 Remaster  0iIZ1fqdUIfcE8CIndhlDD
# 928                            Bring The Pain  3F3R4uyTMkX9jRCEVVmdz6
# 929                     Dark Comedy Late Show  77wywwkLtE5mlrHMrlfSAP
#
#               song_artist
# 0          Kendrick Lamar
# 1      Tyler, The Creator
# 2          Run The Jewels
# 3                 MF DOOM
# 4              Atmosphere
# ..                    ...
# 925               J. Cole
# 926         Royce Da 5'9"
# 927  The Notorious B.I.G.
# 928            Method Man
# 929       Open Mike Eagle
#
# [930 rows x 3 columns]

# %%
feats1=sp.audio_features(tracks=song_ID[0:99])
feats2=sp.audio_features(tracks=song_ID[99:199])
feats3=sp.audio_features(tracks=song_ID[199:299])
feats4=sp.audio_features(tracks=song_ID[299:399])
feats5=sp.audio_features(tracks=song_ID[399:499])
feats6=sp.audio_features(tracks=song_ID[499:599])
feats7=sp.audio_features(tracks=song_ID[599:699])
feats8=sp.audio_features(tracks=song_ID[699:799])
feats9=sp.audio_features(tracks=song_ID[799:899])
feats10=sp.audio_features(tracks=song_ID[899:])

# %%
audio_feat_df1=pd.DataFrame(feats1)
audio_feat_df2=pd.DataFrame(feats2)
audio_feat_df3=pd.DataFrame(feats3)
audio_feat_df4=pd.DataFrame(feats4)
audio_feat_df5=pd.DataFrame(feats5)
audio_feat_df6=pd.DataFrame(feats6)
audio_feat_df7=pd.DataFrame(feats7)
audio_feat_df8=pd.DataFrame(feats8)
audio_feat_df9=pd.DataFrame(feats9)
audio_feat_df10=pd.DataFrame(feats10)

# %%
hiphop = pd.concat([audio_feat_df1,audio_feat_df2,audio_feat_df3,audio_feat_df4,audio_feat_df5,audio_feat_df6,audio_feat_df7,audio_feat_df8,audio_feat_df9,audio_feat_df10], axis=0)

# %%
hiphop = hiphop.reset_index(drop = True)

# %%
hiphop
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.654   0.753   11    -7.556     0       0.3950        0.3030
# 1           0.712   0.759   11    -5.397     1       0.3340        0.0160
# 2           0.507   0.810    6    -6.840     1       0.1050        0.0030
# 3           0.644   0.751    0    -5.652     1       0.2680        0.6620
# 4           0.684   0.397    2   -10.319     1       0.0809        0.2100
# ..            ...     ...  ...       ...   ...          ...           ...
# 925         0.680   0.671    0   -10.647     0       0.2590        0.2840
# 926         0.493   0.928   10    -3.781     0       0.3700        0.2400
# 927         0.738   0.867    4    -5.298     0       0.3860        0.0145
# 928         0.835   0.456    6   -10.195     0       0.2660        0.3800
# 929         0.503   0.833    7    -7.357     0       0.2970        0.2670
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000081     0.130   0.3710  110.722  audio_features
# 1            0.080800     0.217   0.7380   79.103  audio_features
# 2            0.000008     0.314   0.2070  175.710  audio_features
# 3            0.000000     0.170   0.7590   99.948  audio_features
# 4            0.000000     0.235   0.0542   83.027  audio_features
# ..                ...       ...      ...      ...             ...
# 925          0.000000     0.274   0.6080   87.024  audio_features
# 926          0.000000     0.685   0.7510   93.309  audio_features
# 927          0.000000     0.111   0.3550   93.706  audio_features
# 928          0.003590     0.160   0.2240  101.889  audio_features
# 929          0.000000     0.345   0.5140  153.934  audio_features
#
#                          id                                   uri  \
# 0    1Z2FvDFZSDQ23s4BDqpWqZ  spotify:track:1Z2FvDFZSDQ23s4BDqpWqZ
# 1    4OKXvqtfwlvY2fYJ2lzHPH  spotify:track:4OKXvqtfwlvY2fYJ2lzHPH
# 2    0VLYOGNIaiOxEHKWOctcA4  spotify:track:0VLYOGNIaiOxEHKWOctcA4
# 3    12OkZyDWNBLUqoReoseGrc  spotify:track:12OkZyDWNBLUqoReoseGrc
# 4    4O7P2Rug3l4IySk0TEx4Xe  spotify:track:4O7P2Rug3l4IySk0TEx4Xe
# ..                      ...                                   ...
# 925  4sLFhYeZOLJ3G7XmVilAtr  spotify:track:4sLFhYeZOLJ3G7XmVilAtr
# 926  7FUud32IMLTIwb1i5AOUNY  spotify:track:7FUud32IMLTIwb1i5AOUNY
# 927  0iIZ1fqdUIfcE8CIndhlDD  spotify:track:0iIZ1fqdUIfcE8CIndhlDD
# 928  3F3R4uyTMkX9jRCEVVmdz6  spotify:track:3F3R4uyTMkX9jRCEVVmdz6
# 929  77wywwkLtE5mlrHMrlfSAP  spotify:track:77wywwkLtE5mlrHMrlfSAP
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1Z2FvDFZSDQ2...
# 1    https://api.spotify.com/v1/tracks/4OKXvqtfwlvY...
# 2    https://api.spotify.com/v1/tracks/0VLYOGNIaiOx...
# 3    https://api.spotify.com/v1/tracks/12OkZyDWNBLU...
# 4    https://api.spotify.com/v1/tracks/4O7P2Rug3l4I...
# ..                                                 ...
# 925  https://api.spotify.com/v1/tracks/4sLFhYeZOLJ3...
# 926  https://api.spotify.com/v1/tracks/7FUud32IMLTI...
# 927  https://api.spotify.com/v1/tracks/0iIZ1fqdUIfc...
# 928  https://api.spotify.com/v1/tracks/3F3R4uyTMkX9...
# 929  https://api.spotify.com/v1/tracks/77wywwkLtE5m...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1Z2F...       723573
# 1    https://api.spotify.com/v1/audio-analysis/4OKX...       249333
# 2    https://api.spotify.com/v1/audio-analysis/0VLY...       309840
# 3    https://api.spotify.com/v1/audio-analysis/12Ok...       258613
# 4    https://api.spotify.com/v1/audio-analysis/4O7P...       256348
# ..                                                 ...          ...
# 925  https://api.spotify.com/v1/audio-analysis/4sLF...       189293
# 926  https://api.spotify.com/v1/audio-analysis/7FUu...       404667
# 927  https://api.spotify.com/v1/audio-analysis/0iIZ...       259667
# 928  https://api.spotify.com/v1/audio-analysis/3F3R...       189760
# 929  https://api.spotify.com/v1/audio-analysis/77wy...       315121
#
#      time_signature
# 0                 5
# 1                 4
# 2                 5
# 3                 4
# 4                 4
# ..              ...
# 925               4
# 926               4
# 927               4
# 928               4
# 929               4
#
# [930 rows x 18 columns]

# %%
hiphop_df = pd.concat([playlist_song_info, hiphop], axis=1)

# %%
hiphop_df
# Out:
#                                     song_name                 song_ID  \
# 0          Sing About Me, I'm Dying Of Thirst  1Z2FvDFZSDQ23s4BDqpWqZ
# 1                                     Yonkers  4OKXvqtfwlvY2fYJ2lzHPH
# 2                                Angel Duster  0VLYOGNIaiOxEHKWOctcA4
# 3                           Rhymes Like Dimes  12OkZyDWNBLUqoReoseGrc
# 4                             The Last to Say  4O7P2Rug3l4IySk0TEx4Xe
# ..                                        ...                     ...
# 925                           Dead Presidents  4sLFhYeZOLJ3G7XmVilAtr
# 926                      Dead President Heads  7FUud32IMLTIwb1i5AOUNY
# 927  Last Day (feat. The Lox) - 2014 Remaster  0iIZ1fqdUIfcE8CIndhlDD
# 928                            Bring The Pain  3F3R4uyTMkX9jRCEVVmdz6
# 929                     Dark Comedy Late Show  77wywwkLtE5mlrHMrlfSAP
#
#               song_artist  danceability  energy  key  loudness  mode  \
# 0          Kendrick Lamar         0.654   0.753   11    -7.556     0
# 1      Tyler, The Creator         0.712   0.759   11    -5.397     1
# 2          Run The Jewels         0.507   0.810    6    -6.840     1
# 3                 MF DOOM         0.644   0.751    0    -5.652     1
# 4              Atmosphere         0.684   0.397    2   -10.319     1
# ..                    ...           ...     ...  ...       ...   ...
# 925               J. Cole         0.680   0.671    0   -10.647     0
# 926         Royce Da 5'9"         0.493   0.928   10    -3.781     0
# 927  The Notorious B.I.G.         0.738   0.867    4    -5.298     0
# 928            Method Man         0.835   0.456    6   -10.195     0
# 929       Open Mike Eagle         0.503   0.833    7    -7.357     0
#
#      speechiness  acousticness  ...  liveness  valence    tempo  \
# 0         0.3950        0.3030  ...     0.130   0.3710  110.722
# 1         0.3340        0.0160  ...     0.217   0.7380   79.103
# 2         0.1050        0.0030  ...     0.314   0.2070  175.710
# 3         0.2680        0.6620  ...     0.170   0.7590   99.948
# 4         0.0809        0.2100  ...     0.235   0.0542   83.027
# ..           ...           ...  ...       ...      ...      ...
# 925       0.2590        0.2840  ...     0.274   0.6080   87.024
# 926       0.3700        0.2400  ...     0.685   0.7510   93.309
# 927       0.3860        0.0145  ...     0.111   0.3550   93.706
# 928       0.2660        0.3800  ...     0.160   0.2240  101.889
# 929       0.2970        0.2670  ...     0.345   0.5140  153.934
#
#                type                      id  \
# 0    audio_features  1Z2FvDFZSDQ23s4BDqpWqZ
# 1    audio_features  4OKXvqtfwlvY2fYJ2lzHPH
# 2    audio_features  0VLYOGNIaiOxEHKWOctcA4
# 3    audio_features  12OkZyDWNBLUqoReoseGrc
# 4    audio_features  4O7P2Rug3l4IySk0TEx4Xe
# ..              ...                     ...
# 925  audio_features  4sLFhYeZOLJ3G7XmVilAtr
# 926  audio_features  7FUud32IMLTIwb1i5AOUNY
# 927  audio_features  0iIZ1fqdUIfcE8CIndhlDD
# 928  audio_features  3F3R4uyTMkX9jRCEVVmdz6
# 929  audio_features  77wywwkLtE5mlrHMrlfSAP
#
#                                       uri  \
# 0    spotify:track:1Z2FvDFZSDQ23s4BDqpWqZ
# 1    spotify:track:4OKXvqtfwlvY2fYJ2lzHPH
# 2    spotify:track:0VLYOGNIaiOxEHKWOctcA4
# 3    spotify:track:12OkZyDWNBLUqoReoseGrc
# 4    spotify:track:4O7P2Rug3l4IySk0TEx4Xe
# ..                                    ...
# 925  spotify:track:4sLFhYeZOLJ3G7XmVilAtr
# 926  spotify:track:7FUud32IMLTIwb1i5AOUNY
# 927  spotify:track:0iIZ1fqdUIfcE8CIndhlDD
# 928  spotify:track:3F3R4uyTMkX9jRCEVVmdz6
# 929  spotify:track:77wywwkLtE5mlrHMrlfSAP
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1Z2FvDFZSDQ2...
# 1    https://api.spotify.com/v1/tracks/4OKXvqtfwlvY...
# 2    https://api.spotify.com/v1/tracks/0VLYOGNIaiOx...
# 3    https://api.spotify.com/v1/tracks/12OkZyDWNBLU...
# 4    https://api.spotify.com/v1/tracks/4O7P2Rug3l4I...
# ..                                                 ...
# 925  https://api.spotify.com/v1/tracks/4sLFhYeZOLJ3...
# 926  https://api.spotify.com/v1/tracks/7FUud32IMLTI...
# 927  https://api.spotify.com/v1/tracks/0iIZ1fqdUIfc...
# 928  https://api.spotify.com/v1/tracks/3F3R4uyTMkX9...
# 929  https://api.spotify.com/v1/tracks/77wywwkLtE5m...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1Z2F...      723573
# 1    https://api.spotify.com/v1/audio-analysis/4OKX...      249333
# 2    https://api.spotify.com/v1/audio-analysis/0VLY...      309840
# 3    https://api.spotify.com/v1/audio-analysis/12Ok...      258613
# 4    https://api.spotify.com/v1/audio-analysis/4O7P...      256348
# ..                                                 ...         ...
# 925  https://api.spotify.com/v1/audio-analysis/4sLF...      189293
# 926  https://api.spotify.com/v1/audio-analysis/7FUu...      404667
# 927  https://api.spotify.com/v1/audio-analysis/0iIZ...      259667
# 928  https://api.spotify.com/v1/audio-analysis/3F3R...      189760
# 929  https://api.spotify.com/v1/audio-analysis/77wy...      315121
#
#      time_signature
# 0                 5
# 1                 4
# 2                 5
# 3                 4
# 4                 4
# ..              ...
# 925               4
# 926               4
# 927               4
# 928               4
# 929               4
#
# [930 rows x 21 columns]

# %% [markdown]
# ## Jazz Playlist

# %% [markdown]
# - **user name:** "Mick Winsor"
# - **playlist id:** "1NOVRJzehX1cVrA2DFxfBh"

# %%
results3=get_playlist_tracks("Mick Winsor","1NOVRJzehX1cVrA2DFxfBh")

# %%
song_name2=[]
song_ID2=[]
song_artist2=[]
playlist2=results3

# %%
for r in results3: 
    song_ID2.append(r["track"]["id"])

# %%
for r in results3: 
    song_name2.append(r["track"]["name"])

# %%
for r in results3: 
    song_artist2.append(r["track"]["artists"][0]["name"])

# %%
playlist_song_info2=pd.DataFrame({"song_name":song_name2,"song_ID":song_ID2,"song_artist":song_artist2})

# %%
feats1j=sp.audio_features(tracks=song_ID2[0:99])
feats2j=sp.audio_features(tracks=song_ID2[99:199])
feats3j=sp.audio_features(tracks=song_ID2[199:299])
feats4j=sp.audio_features(tracks=song_ID2[299:399])
feats5j=sp.audio_features(tracks=song_ID2[399:499])
feats6j=sp.audio_features(tracks=song_ID2[499:599])
feats7j=sp.audio_features(tracks=song_ID2[599:699])
feats8j=sp.audio_features(tracks=song_ID2[699:])

# %%
audio_feat_df1j=pd.DataFrame(feats1j)
audio_feat_df2j=pd.DataFrame(feats2j)
audio_feat_df3j=pd.DataFrame(feats3j)
audio_feat_df4j=pd.DataFrame(feats4j)
audio_feat_df5j=pd.DataFrame(feats5j)
audio_feat_df6j=pd.DataFrame(feats6j)
audio_feat_df7j=pd.DataFrame(feats7j)
audio_feat_df8j=pd.DataFrame(feats8j)

# %%
jazz = pd.concat([audio_feat_df1j,audio_feat_df2j,audio_feat_df3j,audio_feat_df4j,audio_feat_df5j,audio_feat_df6j,audio_feat_df7j,audio_feat_df8j], axis=0)

# %%
jazz = jazz.reset_index(drop = True)

# %%
jazz
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.446  0.1180    1   -14.663     1       0.0338         0.919
# 1           0.498  0.2930    8   -10.329     1       0.0436         0.779
# 2           0.644  0.1570    7   -16.323     0       0.0407         0.991
# 3           0.542  0.3200    8    -9.975     1       0.0387         0.907
# 4           0.541  0.1580    0   -12.490     1       0.0490         0.986
# ..            ...     ...  ...       ...   ...          ...           ...
# 734         0.286  0.5360    7    -8.091     0       0.0547         0.776
# 735         0.338  0.2550    3   -10.930     1       0.0364         0.938
# 736         0.517  0.1890    5   -17.187     1       0.0377         0.949
# 737         0.536  0.3170    4   -15.238     0       0.2730         0.679
# 738         0.344  0.0596    3   -16.766     1       0.0394         0.947
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.114000    0.1110   0.1160   79.696  audio_features
# 1            0.897000    0.1410   0.4390  146.404  audio_features
# 2            0.920000    0.1010   0.4480   82.251  audio_features
# 3            0.649000    0.0609   0.2060  116.648  audio_features
# 4            0.632000    0.0713   0.3570   74.289  audio_features
# ..                ...       ...      ...      ...             ...
# 734          0.149000    0.7620   0.2010   69.488  audio_features
# 735          0.000493    0.1460   0.0817  129.538  audio_features
# 736          0.842000    0.1020   0.6220  119.030  audio_features
# 737          0.000000    0.3620   0.7390   76.209  audio_features
# 738          0.000060    0.1810   0.1500   81.037  audio_features
#
#                          id                                   uri  \
# 0    2LwUU9aaoKxjnnHQRXHAIq  spotify:track:2LwUU9aaoKxjnnHQRXHAIq
# 1    56Jbks3flnrqbGqBzFCxIS  spotify:track:56Jbks3flnrqbGqBzFCxIS
# 2    4PN5gbJNYWx9yQ6hJepPbG  spotify:track:4PN5gbJNYWx9yQ6hJepPbG
# 3    1wl5b2lw3YagQtZiYZbQWP  spotify:track:1wl5b2lw3YagQtZiYZbQWP
# 4    47sC74TvEcxEYrC8r8OT8X  spotify:track:47sC74TvEcxEYrC8r8OT8X
# ..                      ...                                   ...
# 734  3OOS8eOUU1B2ZuottFya2i  spotify:track:3OOS8eOUU1B2ZuottFya2i
# 735  5P9guvAyGzysMhzMyADHOQ  spotify:track:5P9guvAyGzysMhzMyADHOQ
# 736  0fk8iwRgObJKhJj0UEKiOO  spotify:track:0fk8iwRgObJKhJj0UEKiOO
# 737  5WhWW5j7sYCLYaJOZGLvkj  spotify:track:5WhWW5j7sYCLYaJOZGLvkj
# 738  4xRdYnoXKNDPPrEicGPGCe  spotify:track:4xRdYnoXKNDPPrEicGPGCe
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2LwUU9aaoKxj...
# 1    https://api.spotify.com/v1/tracks/56Jbks3flnrq...
# 2    https://api.spotify.com/v1/tracks/4PN5gbJNYWx9...
# 3    https://api.spotify.com/v1/tracks/1wl5b2lw3Yag...
# 4    https://api.spotify.com/v1/tracks/47sC74TvEcxE...
# ..                                                 ...
# 734  https://api.spotify.com/v1/tracks/3OOS8eOUU1B2...
# 735  https://api.spotify.com/v1/tracks/5P9guvAyGzys...
# 736  https://api.spotify.com/v1/tracks/0fk8iwRgObJK...
# 737  https://api.spotify.com/v1/tracks/5WhWW5j7sYCL...
# 738  https://api.spotify.com/v1/tracks/4xRdYnoXKNDP...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2LwU...       354667
# 1    https://api.spotify.com/v1/audio-analysis/56Jb...       471653
# 2    https://api.spotify.com/v1/audio-analysis/4PN5...       252267
# 3    https://api.spotify.com/v1/audio-analysis/1wl5...       193840
# 4    https://api.spotify.com/v1/audio-analysis/47sC...       287293
# ..                                                 ...          ...
# 734  https://api.spotify.com/v1/audio-analysis/3OOS...       245707
# 735  https://api.spotify.com/v1/audio-analysis/5P9g...       194627
# 736  https://api.spotify.com/v1/audio-analysis/0fk8...       283267
# 737  https://api.spotify.com/v1/audio-analysis/5WhW...       166827
# 738  https://api.spotify.com/v1/audio-analysis/4xRd...       184293
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 734               4
# 735               4
# 736               4
# 737               4
# 738               4
#
# [739 rows x 18 columns]

# %%
jazz_df = pd.concat([playlist_song_info2, jazz], axis=1)

# %%
jazz_df
# Out:
#                                          song_name                 song_ID  \
# 0                                    Body and Soul  2LwUU9aaoKxjnnHQRXHAIq
# 1       All The Things You Are / 52nd Street Theme  56Jbks3flnrqbGqBzFCxIS
# 2                                       Summertime  4PN5gbJNYWx9yQ6hJepPbG
# 3                                  'Round Midnight  1wl5b2lw3YagQtZiYZbQWP
# 4    I Can't Get Started - Digitally Mastered 1989  47sC74TvEcxEYrC8r8OT8X
# ..                                             ...                     ...
# 734                               Wives and Lovers  3OOS8eOUU1B2ZuottFya2i
# 735                              This Is All I Ask  5P9guvAyGzysMhzMyADHOQ
# 736                                 Doggin' Around  0fk8iwRgObJKhJj0UEKiOO
# 737                                  I Won't Dance  5WhWW5j7sYCLYaJOZGLvkj
# 738                                To Each His Own  4xRdYnoXKNDPPrEicGPGCe
#
#                                       song_artist  danceability  energy  key  \
# 0                                  Herbie Hancock         0.446  0.1180    1
# 1                                  Charlie Parker         0.498  0.2930    8
# 2                                   Sidney Bechet         0.644  0.1570    7
# 3                                 Thelonious Monk         0.542  0.3200    8
# 4                 Bunny Berigan and His Orchestra         0.541  0.1580    0
# ..                                            ...           ...     ...  ...
# 734  Burt Bacharach & David Sanborn & George Duke         0.286  0.5360    7
# 735                                  Tony Bennett         0.338  0.2550    3
# 736               Buddy Tate and Abdullah Ibrahim         0.517  0.1890    5
# 737                                Blossom Dearie         0.536  0.3170    4
# 738                                   Eddy Howard         0.344  0.0596    3
#
#      loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0     -14.663     1       0.0338         0.919  ...    0.1110   0.1160
# 1     -10.329     1       0.0436         0.779  ...    0.1410   0.4390
# 2     -16.323     0       0.0407         0.991  ...    0.1010   0.4480
# 3      -9.975     1       0.0387         0.907  ...    0.0609   0.2060
# 4     -12.490     1       0.0490         0.986  ...    0.0713   0.3570
# ..        ...   ...          ...           ...  ...       ...      ...
# 734    -8.091     0       0.0547         0.776  ...    0.7620   0.2010
# 735   -10.930     1       0.0364         0.938  ...    0.1460   0.0817
# 736   -17.187     1       0.0377         0.949  ...    0.1020   0.6220
# 737   -15.238     0       0.2730         0.679  ...    0.3620   0.7390
# 738   -16.766     1       0.0394         0.947  ...    0.1810   0.1500
#
#        tempo            type                      id  \
# 0     79.696  audio_features  2LwUU9aaoKxjnnHQRXHAIq
# 1    146.404  audio_features  56Jbks3flnrqbGqBzFCxIS
# 2     82.251  audio_features  4PN5gbJNYWx9yQ6hJepPbG
# 3    116.648  audio_features  1wl5b2lw3YagQtZiYZbQWP
# 4     74.289  audio_features  47sC74TvEcxEYrC8r8OT8X
# ..       ...             ...                     ...
# 734   69.488  audio_features  3OOS8eOUU1B2ZuottFya2i
# 735  129.538  audio_features  5P9guvAyGzysMhzMyADHOQ
# 736  119.030  audio_features  0fk8iwRgObJKhJj0UEKiOO
# 737   76.209  audio_features  5WhWW5j7sYCLYaJOZGLvkj
# 738   81.037  audio_features  4xRdYnoXKNDPPrEicGPGCe
#
#                                       uri  \
# 0    spotify:track:2LwUU9aaoKxjnnHQRXHAIq
# 1    spotify:track:56Jbks3flnrqbGqBzFCxIS
# 2    spotify:track:4PN5gbJNYWx9yQ6hJepPbG
# 3    spotify:track:1wl5b2lw3YagQtZiYZbQWP
# 4    spotify:track:47sC74TvEcxEYrC8r8OT8X
# ..                                    ...
# 734  spotify:track:3OOS8eOUU1B2ZuottFya2i
# 735  spotify:track:5P9guvAyGzysMhzMyADHOQ
# 736  spotify:track:0fk8iwRgObJKhJj0UEKiOO
# 737  spotify:track:5WhWW5j7sYCLYaJOZGLvkj
# 738  spotify:track:4xRdYnoXKNDPPrEicGPGCe
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2LwUU9aaoKxj...
# 1    https://api.spotify.com/v1/tracks/56Jbks3flnrq...
# 2    https://api.spotify.com/v1/tracks/4PN5gbJNYWx9...
# 3    https://api.spotify.com/v1/tracks/1wl5b2lw3Yag...
# 4    https://api.spotify.com/v1/tracks/47sC74TvEcxE...
# ..                                                 ...
# 734  https://api.spotify.com/v1/tracks/3OOS8eOUU1B2...
# 735  https://api.spotify.com/v1/tracks/5P9guvAyGzys...
# 736  https://api.spotify.com/v1/tracks/0fk8iwRgObJK...
# 737  https://api.spotify.com/v1/tracks/5WhWW5j7sYCL...
# 738  https://api.spotify.com/v1/tracks/4xRdYnoXKNDP...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2LwU...      354667
# 1    https://api.spotify.com/v1/audio-analysis/56Jb...      471653
# 2    https://api.spotify.com/v1/audio-analysis/4PN5...      252267
# 3    https://api.spotify.com/v1/audio-analysis/1wl5...      193840
# 4    https://api.spotify.com/v1/audio-analysis/47sC...      287293
# ..                                                 ...         ...
# 734  https://api.spotify.com/v1/audio-analysis/3OOS...      245707
# 735  https://api.spotify.com/v1/audio-analysis/5P9g...      194627
# 736  https://api.spotify.com/v1/audio-analysis/0fk8...      283267
# 737  https://api.spotify.com/v1/audio-analysis/5WhW...      166827
# 738  https://api.spotify.com/v1/audio-analysis/4xRd...      184293
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 734               4
# 735               4
# 736               4
# 737               4
# 738               4
#
# [739 rows x 21 columns]

# %% [markdown]
# ## Country Playlist

# %% [markdown]
# - **user name:** "CoolBoiJarred"
# - **playlist id:** "552GnK5p9v1c4WMmQbMZxe"

# %%
results4=get_playlist_tracks("CoolBoiJarred","552GnK5p9v1c4WMmQbMZxe")

# %%
song_name3=[]
song_ID3=[]
song_artist3=[]
playlist=results4

for r in results4: 
    song_ID3.append(r["track"]["id"])
for r in results4: 
    song_name3.append(r["track"]["name"])
for r in results4:
    song_artist3.append(r["track"]["artists"][0]["name"])
    
playlist_song_info3=pd.DataFrame({"song_name":song_name3,"song_ID":song_ID3,"song_artist":song_artist3})

feats1c=sp.audio_features(tracks=song_ID3[0:99])
feats2c=sp.audio_features(tracks=song_ID3[99:199])
feats3c=sp.audio_features(tracks=song_ID3[199:299])
feats4c=sp.audio_features(tracks=song_ID3[299:399])
feats5c=sp.audio_features(tracks=song_ID3[399:499])
feats6c=sp.audio_features(tracks=song_ID3[499:599])
feats7c=sp.audio_features(tracks=song_ID3[599:699])
feats8c=sp.audio_features(tracks=song_ID3[699:799])
feats9c=sp.audio_features(tracks=song_ID3[799:])

audio_feat_df1c=pd.DataFrame(feats1c)
audio_feat_df2c=pd.DataFrame(feats2c)
audio_feat_df3c=pd.DataFrame(feats3c)
audio_feat_df4c=pd.DataFrame(feats4c)
audio_feat_df5c=pd.DataFrame(feats5c)
audio_feat_df6c=pd.DataFrame(feats6c)
audio_feat_df7c=pd.DataFrame(feats7c)
audio_feat_df8c=pd.DataFrame(feats8c)
audio_feat_df9c=pd.DataFrame(feats9c)


country = pd.concat([audio_feat_df1c,audio_feat_df2c,audio_feat_df3c,audio_feat_df4c,audio_feat_df5c,audio_feat_df6c,audio_feat_df7c,audio_feat_df8c, audio_feat_df9c], axis=0)
country = country.reset_index(drop = True)
country_df = pd.concat([playlist_song_info3, country], axis=1)
country_df
# Out:
#                                         song_name                 song_ID  \
# 0                                        Skid Row  5aL73MPEZMCTRrND6yBVQs
# 1                      If I Had Left It Up To You  7w1OcvLhpUhqfblODRLRsz
# 2                          The Bottle Let Me Down  1IoblMED1GAnd4IbFmOxr4
# 3                                     Mary's Mine  6bqQgQ27lxg1v7ZWqnmBPl
# 4                   Loneliness Is Eating Me Alive  1jP1G9cGluz9bqocCg59LR
# ..                                            ...                     ...
# 877  Heartland - Pure Country/Main Title Sequence  7wh5Hyx9RXc3NfTWYsEsV4
# 878                                    Suspicions  19oPsdlHwigJm2Ewk1ypRb
# 879                             Where I Come From  6ej1QJ8eIYmhsyTlvgDajy
# 880                               Hot Dusty Roads  1wOxTOMMt5N7aw6kBItAW4
# 881                           For What It's Worth  1qRA5BS78u3gME0loMl9AA
#
#                        song_artist  danceability  energy  key  loudness  mode  \
# 0                    Merle Haggard         0.489   0.754    7    -9.066     1
# 1    Merle Haggard & The Strangers         0.729   0.462    0   -12.688     1
# 2                    Merle Haggard         0.680   0.390    9   -10.731     1
# 3    Merle Haggard & The Strangers         0.565   0.241    0   -12.919     1
# 4    Merle Haggard & The Strangers         0.622   0.240    4   -14.608     1
# ..                             ...           ...     ...  ...       ...   ...
# 877                  George Strait         0.557   0.253    3   -15.539     1
# 878                  Eddie Rabbitt         0.601   0.293    5   -16.445     0
# 879                   Alan Jackson         0.726   0.631   11    -8.136     0
# 880            Buffalo Springfield         0.720   0.576    2   -15.118     1
# 881            Buffalo Springfield         0.653   0.519    2   -10.164     1
#
#      speechiness  acousticness  ...  liveness  valence    tempo  \
# 0         0.0450         0.434  ...    0.1540    0.890   76.416
# 1         0.0416         0.406  ...    0.3240    0.716  113.213
# 2         0.0315         0.493  ...    0.1220    0.695  125.840
# 3         0.0280         0.676  ...    0.3760    0.478  105.932
# 4         0.0282         0.470  ...    0.1570    0.458   84.215
# ..           ...           ...  ...       ...      ...      ...
# 877       0.0279         0.632  ...    0.1570    0.322  141.377
# 878       0.0509         0.325  ...    0.0813    0.652  143.362
# 879       0.0334         0.220  ...    0.1930    0.746  124.711
# 880       0.0290         0.271  ...    0.2560    0.947  111.592
# 881       0.0497         0.406  ...    0.1010    0.822   98.883
#
#                type                      id  \
# 0    audio_features  5aL73MPEZMCTRrND6yBVQs
# 1    audio_features  7w1OcvLhpUhqfblODRLRsz
# 2    audio_features  1IoblMED1GAnd4IbFmOxr4
# 3    audio_features  6bqQgQ27lxg1v7ZWqnmBPl
# 4    audio_features  1jP1G9cGluz9bqocCg59LR
# ..              ...                     ...
# 877  audio_features  7wh5Hyx9RXc3NfTWYsEsV4
# 878  audio_features  19oPsdlHwigJm2Ewk1ypRb
# 879  audio_features  6ej1QJ8eIYmhsyTlvgDajy
# 880  audio_features  1wOxTOMMt5N7aw6kBItAW4
# 881  audio_features  1qRA5BS78u3gME0loMl9AA
#
#                                       uri  \
# 0    spotify:track:5aL73MPEZMCTRrND6yBVQs
# 1    spotify:track:7w1OcvLhpUhqfblODRLRsz
# 2    spotify:track:1IoblMED1GAnd4IbFmOxr4
# 3    spotify:track:6bqQgQ27lxg1v7ZWqnmBPl
# 4    spotify:track:1jP1G9cGluz9bqocCg59LR
# ..                                    ...
# 877  spotify:track:7wh5Hyx9RXc3NfTWYsEsV4
# 878  spotify:track:19oPsdlHwigJm2Ewk1ypRb
# 879  spotify:track:6ej1QJ8eIYmhsyTlvgDajy
# 880  spotify:track:1wOxTOMMt5N7aw6kBItAW4
# 881  spotify:track:1qRA5BS78u3gME0loMl9AA
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5aL73MPEZMCT...
# 1    https://api.spotify.com/v1/tracks/7w1OcvLhpUhq...
# 2    https://api.spotify.com/v1/tracks/1IoblMED1GAn...
# 3    https://api.spotify.com/v1/tracks/6bqQgQ27lxg1...
# 4    https://api.spotify.com/v1/tracks/1jP1G9cGluz9...
# ..                                                 ...
# 877  https://api.spotify.com/v1/tracks/7wh5Hyx9RXc3...
# 878  https://api.spotify.com/v1/tracks/19oPsdlHwigJ...
# 879  https://api.spotify.com/v1/tracks/6ej1QJ8eIYmh...
# 880  https://api.spotify.com/v1/tracks/1wOxTOMMt5N7...
# 881  https://api.spotify.com/v1/tracks/1qRA5BS78u3g...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5aL7...      106867
# 1    https://api.spotify.com/v1/audio-analysis/7w1O...      144533
# 2    https://api.spotify.com/v1/audio-analysis/1Iob...      168867
# 3    https://api.spotify.com/v1/audio-analysis/6bqQ...      177907
# 4    https://api.spotify.com/v1/audio-analysis/1jP1...      155573
# ..                                                 ...         ...
# 877  https://api.spotify.com/v1/audio-analysis/7wh5...      164773
# 878  https://api.spotify.com/v1/audio-analysis/19oP...      260867
# 879  https://api.spotify.com/v1/audio-analysis/6ej1...      239240
# 880  https://api.spotify.com/v1/audio-analysis/1wOx...      171733
# 881  https://api.spotify.com/v1/audio-analysis/1qRA...      153693
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 877               4
# 878               4
# 879               4
# 880               4
# 881               4
#
# [882 rows x 21 columns]

# %% [markdown]
# ## Reggaeton Playlist

# %% [markdown]
# - **user name:** "luisnavarropáez"
# - **playlist id:** "3ZDxWBDjraGCNlyKvLcRa2"

# %%
results6=get_playlist_tracks("luisnavarropáez","3ZDxWBDjraGCNlyKvLcRa2")

# %%
song_name5=[]
song_ID5=[]
song_artist5=[]
playlist=results6


for r in results6: 
    song_ID5.append(r["track"]["id"])
for r in results6: 
    song_name5.append(r["track"]["name"])
for r in results6:
    song_artist5.append(r["track"]["artists"][0]["name"])
    
playlist_song_info5=pd.DataFrame({"song_name":song_name5,"song_ID":song_ID5,"song_artist":song_artist5})

feats1r=sp.audio_features(tracks=song_ID5[0:99])
feats2r=sp.audio_features(tracks=song_ID5[99:199])
feats3r=sp.audio_features(tracks=song_ID5[199:299])
feats4r=sp.audio_features(tracks=song_ID5[299:399])
feats5r=sp.audio_features(tracks=song_ID5[399:])


audio_feat_df1r=pd.DataFrame(feats1r)
audio_feat_df2r=pd.DataFrame(feats2r)
audio_feat_df3r=pd.DataFrame(feats3r)
audio_feat_df4r=pd.DataFrame(feats4r)
audio_feat_df5r=pd.DataFrame(feats5r)


reggaeton = pd.concat([audio_feat_df1r,audio_feat_df2r,audio_feat_df3r,audio_feat_df4r,audio_feat_df5r], axis=0)
reggaeton = reggaeton.reset_index(drop = True)
reggaeton_df = pd.concat([playlist_song_info5, reggaeton], axis=1)
reggaeton_df
# Out:
#                       song_name                 song_ID      song_artist  \
# 0    Fiebre (Prod. King DouDou)  5xtxxuIqInrLDSfjA6Co3o         Bad Gyal
# 1                     Jacaranda  0k5kd8IQULAW4hJBwndWs5         Bad Gyal
# 2              Enchochado de Ti  6G8TNOdTBpBPmDdJAvoVhA     Don Patricio
# 3               Quédate conmigo  5tzOL69W6lCp4gAomIXMnJ            Pole.
# 4                        Solita  7rwX0O3RlxqqIjQM8evm5E            Ozuna
# ..                          ...                     ...              ...
# 447                 BENDICIONES  2CoMYp2uIKsT09nreEZnZn        Bad Bunny
# 448                  Nostálgico  2BEcap3xJtmiPaHKyfQi4e          Rvssian
# 449                      París  4bF2y8rR7GUjrd5LNEvej3         Ingratax
# 450               Tacones Rojos  0Be7sopyKMv8Y8npsUkax2  Sebastian Yatra
# 451                         Bar  0lJE8f0lx8mUSfMyxeYpiC             TINI
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.421   0.720    7    -6.257     1       0.0571        0.2660
# 1           0.519   0.689   10    -3.353     1       0.1490        0.0818
# 2           0.556   0.507    7    -6.565     1       0.3510        0.4080
# 3           0.580   0.715    1    -4.740     1       0.0397        0.6770
# 4           0.807   0.633   10    -6.016     0       0.0929        0.0564
# ..            ...     ...  ...       ...   ...          ...           ...
# 447         0.828   0.581   11    -9.909     1       0.0725        0.0378
# 448         0.734   0.846    9    -3.425     0       0.0489        0.1660
# 449         0.570   0.455    1    -5.748     0       0.0996        0.4410
# 450         0.748   0.856   11    -3.517     0       0.0348        0.0824
# 451         0.523   0.691    1    -3.802     1       0.0833        0.1330
#
#      ...  liveness  valence    tempo            type                      id  \
# 0    ...    0.2250    0.240   97.998  audio_features  5xtxxuIqInrLDSfjA6Co3o
# 1    ...    0.2220    0.515   98.412  audio_features  0k5kd8IQULAW4hJBwndWs5
# 2    ...    0.1650    0.531  180.072  audio_features  6G8TNOdTBpBPmDdJAvoVhA
# 3    ...    0.2430    0.460  145.910  audio_features  5tzOL69W6lCp4gAomIXMnJ
# 4    ...    0.1070    0.325  138.038  audio_features  7rwX0O3RlxqqIjQM8evm5E
# ..   ...       ...      ...      ...             ...                     ...
# 447  ...    0.1030    0.843  143.995  audio_features  2CoMYp2uIKsT09nreEZnZn
# 448  ...    0.2350    0.604   98.026  audio_features  2BEcap3xJtmiPaHKyfQi4e
# 449  ...    0.0654    0.399  167.933  audio_features  4bF2y8rR7GUjrd5LNEvej3
# 450  ...    0.1420    0.927  123.031  audio_features  0Be7sopyKMv8Y8npsUkax2
# 451  ...    0.3270    0.677   94.148  audio_features  0lJE8f0lx8mUSfMyxeYpiC
#
#                                       uri  \
# 0    spotify:track:5xtxxuIqInrLDSfjA6Co3o
# 1    spotify:track:0k5kd8IQULAW4hJBwndWs5
# 2    spotify:track:6G8TNOdTBpBPmDdJAvoVhA
# 3    spotify:track:5tzOL69W6lCp4gAomIXMnJ
# 4    spotify:track:7rwX0O3RlxqqIjQM8evm5E
# ..                                    ...
# 447  spotify:track:2CoMYp2uIKsT09nreEZnZn
# 448  spotify:track:2BEcap3xJtmiPaHKyfQi4e
# 449  spotify:track:4bF2y8rR7GUjrd5LNEvej3
# 450  spotify:track:0Be7sopyKMv8Y8npsUkax2
# 451  spotify:track:0lJE8f0lx8mUSfMyxeYpiC
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5xtxxuIqInrL...
# 1    https://api.spotify.com/v1/tracks/0k5kd8IQULAW...
# 2    https://api.spotify.com/v1/tracks/6G8TNOdTBpBP...
# 3    https://api.spotify.com/v1/tracks/5tzOL69W6lCp...
# 4    https://api.spotify.com/v1/tracks/7rwX0O3Rlxqq...
# ..                                                 ...
# 447  https://api.spotify.com/v1/tracks/2CoMYp2uIKsT...
# 448  https://api.spotify.com/v1/tracks/2BEcap3xJtmi...
# 449  https://api.spotify.com/v1/tracks/4bF2y8rR7GUj...
# 450  https://api.spotify.com/v1/tracks/0Be7sopyKMv8...
# 451  https://api.spotify.com/v1/tracks/0lJE8f0lx8mU...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5xtx...      247500
# 1    https://api.spotify.com/v1/audio-analysis/0k5k...      184800
# 2    https://api.spotify.com/v1/audio-analysis/6G8T...      213373
# 3    https://api.spotify.com/v1/audio-analysis/5tzO...      216059
# 4    https://api.spotify.com/v1/audio-analysis/7rwX...      311726
# ..                                                 ...         ...
# 447  https://api.spotify.com/v1/audio-analysis/2CoM...      155060
# 448  https://api.spotify.com/v1/audio-analysis/2BEc...      209884
# 449  https://api.spotify.com/v1/audio-analysis/4bF2...      151429
# 450  https://api.spotify.com/v1/audio-analysis/0Be7...      189320
# 451  https://api.spotify.com/v1/audio-analysis/0lJE...      160213
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 447               4
# 448               4
# 449               4
# 450               4
# 451               4
#
# [452 rows x 21 columns]

# %% [markdown]
# ## Extra Songs Playlist

# %% [markdown]
# - **user name:** "Morgandril"
# - **playlist id:** "0Vxa5sgoyMmWlzqZFPWC8H"

# %%
results5=get_playlist_tracks("Morgandril","0Vxa5sgoyMmWlzqZFPWC8H")

# %%
song_name4=[]
song_ID4=[]
song_artist4=[]
playlist=results5

for r in results5: 
    song_ID4.append(r["track"]["id"])
for r in results5: 
    song_name4.append(r["track"]["name"])
for r in results5:
    song_artist4.append(r["track"]["artists"][0]["name"])
    
playlist_song_info4=pd.DataFrame({"song_name":song_name4,"song_ID":song_ID4,"song_artist":song_artist4})

feats1ex=sp.audio_features(tracks=song_ID4[0:99])
feats2ex=sp.audio_features(tracks=song_ID4[99:126])
feats2_1ex=sp.audio_features(tracks=song_ID4[127:199])
feats3ex=sp.audio_features(tracks=song_ID4[199:299])
feats4ex=sp.audio_features(tracks=song_ID4[299:399])
feats5ex=sp.audio_features(tracks=song_ID4[399:422])
feats5_1ex=sp.audio_features(tracks=song_ID4[423:499])
feats6ex=sp.audio_features(tracks=song_ID4[499:599])
feats7ex=sp.audio_features(tracks=song_ID4[599:699])
feats8ex=sp.audio_features(tracks=song_ID4[699:799])
feats9ex=sp.audio_features(tracks=song_ID4[799:899])
feats10ex=sp.audio_features(tracks=song_ID4[899:999])
feats11ex=sp.audio_features(tracks=song_ID4[999:1099])
feats12ex=sp.audio_features(tracks=song_ID4[1099:1199])
feats13ex=sp.audio_features(tracks=song_ID4[1199:1299])
feats14ex=sp.audio_features(tracks=song_ID4[1299:1399])
feats15ex=sp.audio_features(tracks=song_ID4[1399:1499])
feats16ex=sp.audio_features(tracks=song_ID4[1499:1599])
feats17ex=sp.audio_features(tracks=song_ID4[1599:1699])
feats18ex=sp.audio_features(tracks=song_ID4[1699:1799])
feats19ex=sp.audio_features(tracks=song_ID4[1799:1899])
feats20ex=sp.audio_features(tracks=song_ID4[1899:1999])
feats21ex=sp.audio_features(tracks=song_ID4[1999:2099])
feats22ex=sp.audio_features(tracks=song_ID4[2099:2199])
feats23ex=sp.audio_features(tracks=song_ID4[2199:2299])
feats24ex=sp.audio_features(tracks=song_ID4[2299:2399])
feats25ex=sp.audio_features(tracks=song_ID4[2399:2499])
feats26ex=sp.audio_features(tracks=song_ID4[2499:2599])
feats27ex=sp.audio_features(tracks=song_ID4[2599:2699])
feats28ex=sp.audio_features(tracks=song_ID4[2699:2799])
feats29ex=sp.audio_features(tracks=song_ID4[2799:2899])
feats30ex=sp.audio_features(tracks=song_ID4[2899:2999])
feats31ex=sp.audio_features(tracks=song_ID4[2999:3045])
feats31_1ex=sp.audio_features(tracks=song_ID4[3046:3099])
feats32ex=sp.audio_features(tracks=song_ID4[3099:3199])
feats33ex=sp.audio_features(tracks=song_ID4[3199:3299])
feats34ex=sp.audio_features(tracks=song_ID4[3299:3399])
feats35ex=sp.audio_features(tracks=song_ID4[3399:3499])
feats36ex=sp.audio_features(tracks=song_ID4[3499:])

# %%
audio_feat_df1ex=pd.DataFrame(feats1ex)
audio_feat_df2ex=pd.DataFrame(feats2ex)
audio_feat_df2_1ex=pd.DataFrame(feats2_1ex)
audio_feat_df3ex=pd.DataFrame(feats3ex)
audio_feat_df4ex=pd.DataFrame(feats4ex)
audio_feat_df5ex=pd.DataFrame(feats5ex)
audio_feat_df5_1ex=pd.DataFrame(feats5_1ex)
audio_feat_df6ex=pd.DataFrame(feats6ex)
audio_feat_df7ex=pd.DataFrame(feats7ex)
audio_feat_df8ex=pd.DataFrame(feats8ex)
audio_feat_df9ex=pd.DataFrame(feats9ex)
audio_feat_df10ex=pd.DataFrame(feats10ex)
audio_feat_df11ex=pd.DataFrame(feats11ex)
audio_feat_df12ex=pd.DataFrame(feats12ex)
audio_feat_df13ex=pd.DataFrame(feats13ex)
audio_feat_df14ex=pd.DataFrame(feats14ex)
audio_feat_df15ex=pd.DataFrame(feats15ex)
audio_feat_df16ex=pd.DataFrame(feats16ex)
audio_feat_df17ex=pd.DataFrame(feats17ex)
audio_feat_df18ex=pd.DataFrame(feats18ex)
audio_feat_df19ex=pd.DataFrame(feats19ex)
audio_feat_df20ex=pd.DataFrame(feats20ex)
audio_feat_df21ex=pd.DataFrame(feats21ex)
audio_feat_df22ex=pd.DataFrame(feats22ex)
audio_feat_df23ex=pd.DataFrame(feats23ex)
audio_feat_df24ex=pd.DataFrame(feats24ex)
audio_feat_df25ex=pd.DataFrame(feats25ex)
audio_feat_df26ex=pd.DataFrame(feats26ex)
audio_feat_df27ex=pd.DataFrame(feats27ex)
audio_feat_df28ex=pd.DataFrame(feats28ex)
audio_feat_df29ex=pd.DataFrame(feats29ex)
audio_feat_df30ex=pd.DataFrame(feats30ex)
audio_feat_df31ex=pd.DataFrame(feats31ex)
audio_feat_df31_1ex=pd.DataFrame(feats31_1ex)
audio_feat_df32ex=pd.DataFrame(feats32ex)
audio_feat_df33ex=pd.DataFrame(feats33ex)
audio_feat_df34ex=pd.DataFrame(feats34ex)
audio_feat_df35ex=pd.DataFrame(feats35ex)
audio_feat_df36ex=pd.DataFrame(feats36ex)


extra = pd.concat([audio_feat_df1ex,audio_feat_df2ex,audio_feat_df2_1ex, audio_feat_df3ex,audio_feat_df4ex,audio_feat_df5ex, audio_feat_df5_1ex, audio_feat_df6ex,audio_feat_df7ex,audio_feat_df8ex, audio_feat_df9ex, audio_feat_df10ex, audio_feat_df11ex, audio_feat_df12ex,audio_feat_df13ex,audio_feat_df14ex,audio_feat_df15ex,audio_feat_df16ex,audio_feat_df17ex,audio_feat_df18ex, audio_feat_df19ex, audio_feat_df20ex, audio_feat_df21ex, audio_feat_df22ex,audio_feat_df23ex,audio_feat_df24ex,audio_feat_df25ex,audio_feat_df26ex,audio_feat_df27ex,audio_feat_df28ex, audio_feat_df29ex, audio_feat_df30ex, audio_feat_df31ex, audio_feat_df31_1ex, audio_feat_df32ex, audio_feat_df33ex, audio_feat_df34ex, audio_feat_df35ex], axis=0)
extra = extra.reset_index(drop = True)
extra
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.544  0.4290    2   -16.308     0       0.0338       0.59700
# 1            0.824  0.4790   11    -9.214     0       0.1240       0.07820
# 2            0.514  0.0761   10   -25.348     1       0.1490       0.93000
# 3            0.521  0.5570    5   -10.829     1       0.0627       0.05610
# 4            0.471  0.5320    4    -7.915     0       0.1820       0.00902
# ...            ...     ...  ...       ...   ...          ...           ...
# 3491         0.652  0.2230    2   -17.351     0       0.4170       0.78500
# 3492         0.709  0.2580    6   -15.540     1       0.0386       0.34200
# 3493         0.441  0.4030   11    -9.570     1       0.1210       0.40600
# 3494         0.597  0.3950    4   -20.747     0       0.0623       0.78500
# 3495         0.771  0.4570    1    -9.740     0       0.0937       0.27300
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0                0.836    0.3550   0.0577  120.063  audio_features
# 1                0.872    0.0734   0.1970   93.993  audio_features
# 2                0.924    0.5970   0.4570  122.845  audio_features
# 3                0.904    0.0806   0.4110  199.996  audio_features
# 4                0.164    0.3090   0.6610  179.291  audio_features
# ...                ...       ...      ...      ...             ...
# 3491             0.212    0.0997   0.5110  164.128  audio_features
# 3492             0.909    0.1200   0.1400  142.542  audio_features
# 3493             0.824    0.1780   0.2790  163.591  audio_features
# 3494             0.920    0.1150   0.0894  171.966  audio_features
# 3495             0.706    0.1100   0.4860   80.006  audio_features
#
#                           id                                   uri  \
# 0     3PmEzB2ORXmXBx07JY9z66  spotify:track:3PmEzB2ORXmXBx07JY9z66
# 1     7H8rKglhpQKgRdXJFa4E8A  spotify:track:7H8rKglhpQKgRdXJFa4E8A
# 2     5wM0wGcE0BmGwH9Y4iDKDZ  spotify:track:5wM0wGcE0BmGwH9Y4iDKDZ
# 3     4Sderi6uOqf0UzGmmuMrcK  spotify:track:4Sderi6uOqf0UzGmmuMrcK
# 4     0AlTlyiZPI2RAuBrwkK841  spotify:track:0AlTlyiZPI2RAuBrwkK841
# ...                      ...                                   ...
# 3491  4KY9vmJS55o2AAMbR5zDfg  spotify:track:4KY9vmJS55o2AAMbR5zDfg
# 3492  3xK38Jy0gEs7yprInWoFZQ  spotify:track:3xK38Jy0gEs7yprInWoFZQ
# 3493  1LHiyDf1Oh3g2fzpPiz0Fv  spotify:track:1LHiyDf1Oh3g2fzpPiz0Fv
# 3494  0I8Pn5LBI4TIydkOxOeEmE  spotify:track:0I8Pn5LBI4TIydkOxOeEmE
# 3495  4rkZDZwmAKS16xvVt9dTf0  spotify:track:4rkZDZwmAKS16xvVt9dTf0
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3PmEzB2ORXmX...
# 1     https://api.spotify.com/v1/tracks/7H8rKglhpQKg...
# 2     https://api.spotify.com/v1/tracks/5wM0wGcE0BmG...
# 3     https://api.spotify.com/v1/tracks/4Sderi6uOqf0...
# 4     https://api.spotify.com/v1/tracks/0AlTlyiZPI2R...
# ...                                                 ...
# 3491  https://api.spotify.com/v1/tracks/4KY9vmJS55o2...
# 3492  https://api.spotify.com/v1/tracks/3xK38Jy0gEs7...
# 3493  https://api.spotify.com/v1/tracks/1LHiyDf1Oh3g...
# 3494  https://api.spotify.com/v1/tracks/0I8Pn5LBI4TI...
# 3495  https://api.spotify.com/v1/tracks/4rkZDZwmAKS1...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3PmE...       372000
# 1     https://api.spotify.com/v1/audio-analysis/7H8r...       127660
# 2     https://api.spotify.com/v1/audio-analysis/5wM0...        98919
# 3     https://api.spotify.com/v1/audio-analysis/4Sde...       177374
# 4     https://api.spotify.com/v1/audio-analysis/0AlT...       145697
# ...                                                 ...          ...
# 3491  https://api.spotify.com/v1/audio-analysis/4KY9...        77575
# 3492  https://api.spotify.com/v1/audio-analysis/3xK3...       154900
# 3493  https://api.spotify.com/v1/audio-analysis/1LHi...       160720
# 3494  https://api.spotify.com/v1/audio-analysis/0I8P...       129767
# 3495  https://api.spotify.com/v1/audio-analysis/4rkZ...       144000
#
#       time_signature
# 0                  4
# 1                  4
# 2                  1
# 3                  4
# 4                  4
# ...              ...
# 3491               4
# 3492               4
# 3493               4
# 3494               4
# 3495               4
#
# [3496 rows x 18 columns]

# %%
extra_df = pd.merge(left=extra, right=playlist_song_info4, how='left', left_on="id", right_on='song_ID')
extra_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.544  0.4290    2   -16.308     0       0.0338       0.59700
# 1            0.824  0.4790   11    -9.214     0       0.1240       0.07820
# 2            0.514  0.0761   10   -25.348     1       0.1490       0.93000
# 3            0.521  0.5570    5   -10.829     1       0.0627       0.05610
# 4            0.471  0.5320    4    -7.915     0       0.1820       0.00902
# ...            ...     ...  ...       ...   ...          ...           ...
# 3499         0.652  0.2230    2   -17.351     0       0.4170       0.78500
# 3500         0.709  0.2580    6   -15.540     1       0.0386       0.34200
# 3501         0.441  0.4030   11    -9.570     1       0.1210       0.40600
# 3502         0.597  0.3950    4   -20.747     0       0.0623       0.78500
# 3503         0.771  0.4570    1    -9.740     0       0.0937       0.27300
#
#       instrumentalness  liveness  valence  ...            type  \
# 0                0.836    0.3550   0.0577  ...  audio_features
# 1                0.872    0.0734   0.1970  ...  audio_features
# 2                0.924    0.5970   0.4570  ...  audio_features
# 3                0.904    0.0806   0.4110  ...  audio_features
# 4                0.164    0.3090   0.6610  ...  audio_features
# ...                ...       ...      ...  ...             ...
# 3499             0.212    0.0997   0.5110  ...  audio_features
# 3500             0.909    0.1200   0.1400  ...  audio_features
# 3501             0.824    0.1780   0.2790  ...  audio_features
# 3502             0.920    0.1150   0.0894  ...  audio_features
# 3503             0.706    0.1100   0.4860  ...  audio_features
#
#                           id                                   uri  \
# 0     3PmEzB2ORXmXBx07JY9z66  spotify:track:3PmEzB2ORXmXBx07JY9z66
# 1     7H8rKglhpQKgRdXJFa4E8A  spotify:track:7H8rKglhpQKgRdXJFa4E8A
# 2     5wM0wGcE0BmGwH9Y4iDKDZ  spotify:track:5wM0wGcE0BmGwH9Y4iDKDZ
# 3     4Sderi6uOqf0UzGmmuMrcK  spotify:track:4Sderi6uOqf0UzGmmuMrcK
# 4     0AlTlyiZPI2RAuBrwkK841  spotify:track:0AlTlyiZPI2RAuBrwkK841
# ...                      ...                                   ...
# 3499  4KY9vmJS55o2AAMbR5zDfg  spotify:track:4KY9vmJS55o2AAMbR5zDfg
# 3500  3xK38Jy0gEs7yprInWoFZQ  spotify:track:3xK38Jy0gEs7yprInWoFZQ
# 3501  1LHiyDf1Oh3g2fzpPiz0Fv  spotify:track:1LHiyDf1Oh3g2fzpPiz0Fv
# 3502  0I8Pn5LBI4TIydkOxOeEmE  spotify:track:0I8Pn5LBI4TIydkOxOeEmE
# 3503  4rkZDZwmAKS16xvVt9dTf0  spotify:track:4rkZDZwmAKS16xvVt9dTf0
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3PmEzB2ORXmX...
# 1     https://api.spotify.com/v1/tracks/7H8rKglhpQKg...
# 2     https://api.spotify.com/v1/tracks/5wM0wGcE0BmG...
# 3     https://api.spotify.com/v1/tracks/4Sderi6uOqf0...
# 4     https://api.spotify.com/v1/tracks/0AlTlyiZPI2R...
# ...                                                 ...
# 3499  https://api.spotify.com/v1/tracks/4KY9vmJS55o2...
# 3500  https://api.spotify.com/v1/tracks/3xK38Jy0gEs7...
# 3501  https://api.spotify.com/v1/tracks/1LHiyDf1Oh3g...
# 3502  https://api.spotify.com/v1/tracks/0I8Pn5LBI4TI...
# 3503  https://api.spotify.com/v1/tracks/4rkZDZwmAKS1...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3PmE...      372000
# 1     https://api.spotify.com/v1/audio-analysis/7H8r...      127660
# 2     https://api.spotify.com/v1/audio-analysis/5wM0...       98919
# 3     https://api.spotify.com/v1/audio-analysis/4Sde...      177374
# 4     https://api.spotify.com/v1/audio-analysis/0AlT...      145697
# ...                                                 ...         ...
# 3499  https://api.spotify.com/v1/audio-analysis/4KY9...       77575
# 3500  https://api.spotify.com/v1/audio-analysis/3xK3...      154900
# 3501  https://api.spotify.com/v1/audio-analysis/1LHi...      160720
# 3502  https://api.spotify.com/v1/audio-analysis/0I8P...      129767
# 3503  https://api.spotify.com/v1/audio-analysis/4rkZ...      144000
#
#       time_signature              song_name                 song_ID  \
# 0                  4    Optimistic Nihilism  3PmEzB2ORXmXBx07JY9z66
# 1                  4  Theme from Dissect S4  7H8rKglhpQKgRdXJFa4E8A
# 2                  1            Morning Cup  5wM0wGcE0BmGwH9Y4iDKDZ
# 3                  4           New Machines  4Sderi6uOqf0UzGmmuMrcK
# 4                  4     Doesn't Make Sense  0AlTlyiZPI2RAuBrwkK841
# ...              ...                    ...                     ...
# 3499               4            Last Minute  4KY9vmJS55o2AAMbR5zDfg
# 3500               4           Pool of Swim  3xK38Jy0gEs7yprInWoFZQ
# 3501               4       Kenny Ain't Dead  1LHiyDf1Oh3g2fzpPiz0Fv
# 3502               4        Ciudad de Papel  0I8Pn5LBI4TIydkOxOeEmE
# 3503               4                 Yanagi  4rkZDZwmAKS16xvVt9dTf0
#
#         song_artist
# 0     Epic Mountain
# 1        Birocratic
# 2         ticofaces
# 3              Home
# 4               TLO
# ...             ...
# 3499      High John
# 3500      Papi Pier
# 3501    KaspaHauser
# 3502      Iván Rosa
# 3503         Daruma
#
# [3504 rows x 21 columns]

# %% [markdown]
# ## Top 100 Billboard

# %% [markdown]
# - **user name:** "Billboard"
# - **playlist id:** "6UeSakyzhiEt4NB3UAd6NQ"

# %%
results7=get_playlist_tracks("Billboard","6UeSakyzhiEt4NB3UAd6NQ")

# %%
song_name6=[]
song_ID6=[]
song_artist6=[]
playlist=results7

for r in results7: 
    song_ID6.append(r["track"]["id"])
for r in results7: 
    song_name6.append(r["track"]["name"])
for r in results7:
    song_artist6.append(r["track"]["artists"][0]["name"])

# %%
playlist_song_info6 = pd.DataFrame({"song_name":song_name6,"song_ID":song_ID6,"song_artist":song_artist6})

# %%
feats100_1 = sp.audio_features(tracks=song_ID6[0:99])
feats100_2 = sp.audio_features(tracks=song_ID6[99:])

audio_feat_df100_1=pd.DataFrame(feats100_1)
audio_feat_df100_2=pd.DataFrame(feats100_2)

top100 = pd.concat([audio_feat_df100_1,audio_feat_df100_2], axis=0)
top100 = top100.reset_index(drop = True)

top_100 = pd.concat([playlist_song_info6, top100], axis=1)
top_100
# Out:
#                                              song_name  \
# 0                                           Easy On Me
# 1                            STAY (with Justin Bieber)
# 2                    INDUSTRY BABY (feat. Jack Harlow)
# 3    All Too Well (10 Minute Version) (Taylor's Ver...
# 4                                            Oh My God
# ..                                                 ...
# 112                  Moth To A Flame (with The Weeknd)
# 113                                     'Til You Can't
# 114                                              Woman
# 115                                     Take My Breath
# 116                                        For Tonight
#
#                     song_ID          song_artist  danceability  energy  key  \
# 0    0gplL1WMoJ6iYaPgMCL0gX                Adele         0.604   0.366    5
# 1    5HCyWlXZPP0y6Gqq8TgA20        The Kid LAROI         0.591   0.764    1
# 2    27NovPIUIRrOZoCHxABJwK            Lil Nas X         0.736   0.704    3
# 3    5enxwA8aAbwZbf5qCHORXi         Taylor Swift         0.631   0.518    0
# 4    3Kkjo3cT83cw09VJyrLNwX                Adele         0.534   0.725    1
# ..                      ...                  ...           ...     ...  ...
# 112  2gpWyfu7eZ01zzncHpxOtA  Swedish House Mafia         0.542   0.659    8
# 113  13rC4iKtfQocWIfzPOJxaT         Cody Johnson         0.505   0.814    1
# 114  6Uj1ctrBOjOas8xZXGqKk4             Doja Cat         0.824   0.764    5
# 115  6OGogr19zPTM4BALXuMQpF           The Weeknd         0.748   0.740    8
# 116  61Emqg95O9zo1GNOcyxq4Y               Giveon         0.442   0.517    9
#
#      loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0      -7.519     1       0.0282       0.57800  ...    0.1330    0.130
# 1      -5.484     1       0.0483       0.03830  ...    0.1030    0.478
# 2      -7.409     0       0.0615       0.02030  ...    0.0501    0.894
# 3      -8.771     1       0.0303       0.27400  ...    0.0880    0.205
# 4      -3.906     1       0.0460       0.09100  ...    0.0264    0.550
# ..        ...   ...          ...           ...  ...       ...      ...
# 112    -7.289     1       0.0389       0.00279  ...    0.1050    0.109
# 113    -4.905     1       0.0439       0.05660  ...    0.1060    0.503
# 114    -4.175     0       0.0854       0.08880  ...    0.1170    0.881
# 115    -6.010     1       0.0484       0.01070  ...    0.1010    0.518
# 116    -7.807     1       0.0548       0.06990  ...    0.1140    0.200
#
#        tempo            type                      id  \
# 0    141.981  audio_features  0gplL1WMoJ6iYaPgMCL0gX
# 1    169.928  audio_features  5HCyWlXZPP0y6Gqq8TgA20
# 2    149.995  audio_features  27NovPIUIRrOZoCHxABJwK
# 3     93.023  audio_features  5enxwA8aAbwZbf5qCHORXi
# 4     88.098  audio_features  3Kkjo3cT83cw09VJyrLNwX
# ..       ...             ...                     ...
# 112  120.122  audio_features  2gpWyfu7eZ01zzncHpxOtA
# 113  160.085  audio_features  13rC4iKtfQocWIfzPOJxaT
# 114  107.998  audio_features  6Uj1ctrBOjOas8xZXGqKk4
# 115  121.004  audio_features  6OGogr19zPTM4BALXuMQpF
# 116   79.867  audio_features  61Emqg95O9zo1GNOcyxq4Y
#
#                                       uri  \
# 0    spotify:track:0gplL1WMoJ6iYaPgMCL0gX
# 1    spotify:track:5HCyWlXZPP0y6Gqq8TgA20
# 2    spotify:track:27NovPIUIRrOZoCHxABJwK
# 3    spotify:track:5enxwA8aAbwZbf5qCHORXi
# 4    spotify:track:3Kkjo3cT83cw09VJyrLNwX
# ..                                    ...
# 112  spotify:track:2gpWyfu7eZ01zzncHpxOtA
# 113  spotify:track:13rC4iKtfQocWIfzPOJxaT
# 114  spotify:track:6Uj1ctrBOjOas8xZXGqKk4
# 115  spotify:track:6OGogr19zPTM4BALXuMQpF
# 116  spotify:track:61Emqg95O9zo1GNOcyxq4Y
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0gplL1WMoJ6i...
# 1    https://api.spotify.com/v1/tracks/5HCyWlXZPP0y...
# 2    https://api.spotify.com/v1/tracks/27NovPIUIRrO...
# 3    https://api.spotify.com/v1/tracks/5enxwA8aAbwZ...
# 4    https://api.spotify.com/v1/tracks/3Kkjo3cT83cw...
# ..                                                 ...
# 112  https://api.spotify.com/v1/tracks/2gpWyfu7eZ01...
# 113  https://api.spotify.com/v1/tracks/13rC4iKtfQoc...
# 114  https://api.spotify.com/v1/tracks/6Uj1ctrBOjOa...
# 115  https://api.spotify.com/v1/tracks/6OGogr19zPTM...
# 116  https://api.spotify.com/v1/tracks/61Emqg95O9zo...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0gpl...      224695
# 1    https://api.spotify.com/v1/audio-analysis/5HCy...      141806
# 2    https://api.spotify.com/v1/audio-analysis/27No...      212000
# 3    https://api.spotify.com/v1/audio-analysis/5enx...      613027
# 4    https://api.spotify.com/v1/audio-analysis/3Kkj...      225149
# ..                                                 ...         ...
# 112  https://api.spotify.com/v1/audio-analysis/2gpW...      234000
# 113  https://api.spotify.com/v1/audio-analysis/13rC...      224773
# 114  https://api.spotify.com/v1/audio-analysis/6Uj1...      172627
# 115  https://api.spotify.com/v1/audio-analysis/6OGo...      220196
# 116  https://api.spotify.com/v1/audio-analysis/61Em...      193822
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 112               4
# 113               4
# 114               4
# 115               4
# 116               4
#
# [117 rows x 21 columns]

# %% [markdown]
# # Changing the sort of the columns

# %%
hiphop_df.columns.to_list()
# Out:
# ['song_name',
#  'song_ID',
#  'song_artist',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature']

# %%
hiphop_df = hiphop_df.reindex(columns=['song_name',
 'song_ID',
 'song_artist',
 'type',
 'id',
 'uri',
 'track_href',
 'analysis_url',
 'danceability',
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo',
 'duration_ms',
 'time_signature'])

# %%
jazz_df = jazz_df.reindex(columns=['song_name',
 'song_ID',
 'song_artist',
 'type',
 'id',
 'uri',
 'track_href',
 'analysis_url',
 'danceability',
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo',
 'duration_ms',
 'time_signature'])

# %%
country_df = country_df.reindex(columns=['song_name',
 'song_ID',
 'song_artist',
 'type',
 'id',
 'uri',
 'track_href',
 'analysis_url',
 'danceability',
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo',
 'duration_ms',
 'time_signature'])

# %%
extra_df = extra_df.reindex(columns=['song_name',
 'song_ID',
 'song_artist',
 'type',
 'id',
 'uri',
 'track_href',
 'analysis_url',
 'danceability',
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo',
 'duration_ms',
 'time_signature'])

# %%
reggaeton_df = reggaeton_df.reindex(columns=['song_name',
 'song_ID',
 'song_artist',
 'type',
 'id',
 'uri',
 'track_href',
 'analysis_url',
 'danceability',
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo',
 'duration_ms',
 'time_signature'])

# %%
top_100 = top_100.reindex(columns=['song_name',
 'song_ID',
 'song_artist',
 'type',
 'id',
 'uri',
 'track_href',
 'analysis_url',
 'danceability',
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'liveness',
 'valence',
 'tempo',
 'duration_ms',
 'time_signature'])

# %%
big_df1 = pd.concat([hiphop_df, jazz_df, country_df, reggaeton_df, extra_df, top_100], axis=0)

# %%
big_df1.shape
# Out:
# (6624, 21)

# %%
big_df1.isna().sum()
# Out:
# song_name           0
# song_ID             0
# song_artist         0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# # Scalar

# %%
big_df1_clean = big_df1.drop([ 'song_ID',
 'song_artist',
 'type',
'id',
 'uri',
 'track_href',
 'analysis_url'], axis = 1)

# %%
big_df1_clean.index = big_df1_clean.iloc[:,0]

# %%
big_df1_clean = big_df1_clean.iloc[:,1:]

# %%
big_df1_clean.rename_axis(None, inplace = True)

# %%
big_df1_clean
# Out:
#                                     danceability  energy  key  loudness  mode  \
# Sing About Me, I'm Dying Of Thirst         0.654   0.753   11    -7.556     0
# Yonkers                                    0.712   0.759   11    -5.397     1
# Angel Duster                               0.507   0.810    6    -6.840     1
# Rhymes Like Dimes                          0.644   0.751    0    -5.652     1
# The Last to Say                            0.684   0.397    2   -10.319     1
# ...                                          ...     ...  ...       ...   ...
# Moth To A Flame (with The Weeknd)          0.542   0.659    8    -7.289     1
# 'Til You Can't                             0.505   0.814    1    -4.905     1
# Woman                                      0.824   0.764    5    -4.175     0
# Take My Breath                             0.748   0.740    8    -6.010     1
# For Tonight                                0.442   0.517    9    -7.807     1
#
#                                     speechiness  acousticness  \
# Sing About Me, I'm Dying Of Thirst       0.3950       0.30300
# Yonkers                                  0.3340       0.01600
# Angel Duster                             0.1050       0.00300
# Rhymes Like Dimes                        0.2680       0.66200
# The Last to Say                          0.0809       0.21000
# ...                                         ...           ...
# Moth To A Flame (with The Weeknd)        0.0389       0.00279
# 'Til You Can't                           0.0439       0.05660
# Woman                                    0.0854       0.08880
# Take My Breath                           0.0484       0.01070
# For Tonight                              0.0548       0.06990
#
#                                     instrumentalness  liveness  valence  \
# Sing About Me, I'm Dying Of Thirst          0.000081     0.130   0.3710
# Yonkers                                     0.080800     0.217   0.7380
# Angel Duster                                0.000008     0.314   0.2070
# Rhymes Like Dimes                           0.000000     0.170   0.7590
# The Last to Say                             0.000000     0.235   0.0542
# ...                                              ...       ...      ...
# Moth To A Flame (with The Weeknd)           0.000000     0.105   0.1090
# 'Til You Can't                              0.000000     0.106   0.5030
# Woman                                       0.002940     0.117   0.8810
# Take My Breath                              0.000022     0.101   0.5180
# For Tonight                                 0.000000     0.114   0.2000
#
#                                       tempo  duration_ms  time_signature
# Sing About Me, I'm Dying Of Thirst  110.722       723573               5
# Yonkers                              79.103       249333               4
# Angel Duster                        175.710       309840               5
# Rhymes Like Dimes                    99.948       258613               4
# The Last to Say                      83.027       256348               4
# ...                                     ...          ...             ...
# Moth To A Flame (with The Weeknd)   120.122       234000               4
# 'Til You Can't                      160.085       224773               4
# Woman                               107.998       172627               4
# Take My Breath                      121.004       220196               4
# For Tonight                          79.867       193822               4
#
# [6624 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
big_df1_clean_scaled=StandardScaler().fit_transform(big_df1_clean)

# %%
big_df1_clean.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
big_df1_clean_scaled_df=pd.DataFrame(big_df1_clean_scaled,columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature'])

# %%
big_df1_clean_scaled_df.hist(figsize = (16,8));

# %% [markdown]
# # Finding the Optimal K

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
from sklearn.cluster import KMeans
from sklearn import datasets
import seaborn as sns

# %%
kmeans2 = KMeans(n_clusters = 50)
kmeans2.fit(big_df1_clean_scaled_df)
print(kmeans2.inertia_)
# Out:
# 29563.292807428785

# %%
K = range(25,50)

# %%
inertia1 =[]
for k in K:
    kmeans3 = KMeans(n_clusters = k, random_state = 40)
    kmeans3.fit(big_df1_clean_scaled_df)
    inertia1.append(kmeans3.inertia_)
    
print(inertia1)
# Out:
# [35448.01174048205, 35246.784731012376, 34736.87084430854, 34419.06314593945, 34067.95196452863, 33918.03162505052, 33617.36056256549, 33256.366132525225, 33140.984270224246, 32876.39814360018, 32446.421586294324, 32307.757353088564, 32115.113186015846, 31898.564769990808, 31535.079745054107, 31383.276765758885, 31131.503801242736, 31060.620383686604, 30747.518287577128, 30689.330268002886, 30403.093524210086, 30294.17662775359, 30123.104826796072, 29907.84106598287, 29739.37610321124]

# %%
plt.figure(figsize = (16,8))
plt.plot(K, inertia1, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia1')
plt.xticks(np.arange(min(K), max(K) + 1, 1.0))
plt.title('elbow method, optimal k by inertia');

# %% [markdown]
# The best k seems to be 43

# %% [markdown]
# # Cluster with k = 43

# %% [markdown]
# ## Cluster 1 - No scaled data

# %%
plt.scatter(big_df1_clean.iloc[:,0], big_df1_clean.iloc[:,3], big_df1_clean.iloc[:,1],big_df1_clean.iloc[:,2]);

# %%
kmeans1 = KMeans(n_clusters = 43)

# %%
cluster1 = kmeans1.fit(big_df1_clean )

# %%
cluster1.cluster_centers_
# Out:
# array([[ 6.37054217e-01,  4.19763554e-01,  5.34638554e+00,
#         -1.17844608e+01,  6.56626506e-01,  9.06072289e-02,
#          5.65684509e-01,  4.38821825e-01,  1.65177410e-01,
#          4.68784036e-01,  1.11124623e+02,  1.73432063e+05,
#          3.94578313e+00],
#        [ 6.40514925e-01,  5.73479104e-01,  5.63432836e+00,
#         -9.09479104e+00,  6.11940299e-01,  1.55797761e-01,
#          3.67382619e-01,  1.12044708e-01,  1.87018657e-01,
#          4.90329851e-01,  1.11293746e+02,  2.58118903e+05,
#          3.91044776e+00],
#        [ 6.55864407e-01,  3.14097034e-01,  5.50423729e+00,
#         -1.36105085e+01,  5.38135593e-01,  1.03322034e-01,
#          6.49769068e-01,  7.34339289e-01,  1.55918644e-01,
#          3.97719068e-01,  1.10960097e+02,  1.13966720e+05,
#          3.87288136e+00],
#        [ 5.67809524e-01,  4.84890476e-01,  6.33333333e+00,
#         -1.01539524e+01,  3.80952381e-01,  8.99142857e-02,
#          5.36544762e-01,  4.23551695e-01,  1.97866667e-01,
#          4.81071429e-01,  1.13657762e+02,  4.45827857e+05,
#          3.80952381e+00],
#        [ 5.79918367e-01,  5.05973469e-01,  5.10204082e+00,
#         -1.14208980e+01,  4.89795918e-01,  1.61608163e-01,
#          4.70745878e-01,  2.14592233e-01,  2.94153061e-01,
#          4.92912245e-01,  1.06872020e+02,  3.43330796e+05,
#          3.85714286e+00],
#        [ 6.45580645e-01,  5.84683410e-01,  5.49308756e+00,
#         -8.51941014e+00,  6.63594470e-01,  1.12958525e-01,
#          3.37513937e-01,  1.80551334e-01,  1.84230415e-01,
#          5.21958986e-01,  1.13351088e+02,  2.11284263e+05,
#          3.95852535e+00],
#        [ 6.30679666e-01,  3.28209192e-01,  5.45403900e+00,
#         -1.35226407e+01,  5.76601671e-01,  8.87320334e-02,
#          6.47609861e-01,  6.08016265e-01,  1.66094986e-01,
#          3.85604178e-01,  1.12042969e+02,  1.45605306e+05,
#          3.88857939e+00],
#        [ 5.71333333e-01,  3.72166667e-01,  8.00000000e+00,
#         -1.63676667e+01,  1.66666667e-01,  1.39600000e-01,
#          6.10216667e-01,  4.77018667e-01,  2.27316667e-01,
#          3.59666667e-01,  1.08856833e+02,  5.77071167e+05,
#          4.00000000e+00],
#        [ 6.68137931e-01,  2.87937931e-01,  4.58620690e+00,
#         -1.48899655e+01,  4.82758621e-01,  1.53155172e-01,
#          6.73467021e-01,  7.51776548e-01,  1.33268966e-01,
#          5.24334483e-01,  1.10192172e+02,  5.58905862e+04,
#          3.79310345e+00],
#        [ 6.76164557e-01,  3.10886076e-01,  5.39240506e+00,
#         -1.37885000e+01,  5.50632911e-01,  1.06665190e-01,
#          6.47769051e-01,  7.68944691e-01,  1.52317089e-01,
#          4.07125316e-01,  1.04107405e+02,  9.74420316e+04,
#          3.85443038e+00],
#        [ 6.35637838e-01,  6.29670270e-01,  5.67567568e+00,
#         -8.28604054e+00,  4.72972973e-01,  1.88383784e-01,
#          2.75498257e-01,  6.80535291e-02,  2.19916216e-01,
#          5.04325676e-01,  1.07227297e+02,  3.08625716e+05,
#          4.04054054e+00],
#        [ 6.19980469e-01,  5.30308984e-01,  5.12109375e+00,
#         -9.79311719e+00,  6.56250000e-01,  1.15253516e-01,
#          4.05607543e-01,  1.72804350e-01,  1.84508984e-01,
#          5.26519141e-01,  1.18011391e+02,  2.03712285e+05,
#          3.91015625e+00],
#        [ 4.09500000e-01,  3.06000000e-01,  4.50000000e+00,
#         -1.31525000e+01,  1.00000000e+00,  3.38500000e-02,
#          6.60500000e-01,  2.27845000e-01,  1.51000000e-01,
#          3.58500000e-01,  1.51654500e+02,  8.15653500e+05,
#          3.50000000e+00],
#        [ 6.41715278e-01,  6.14871528e-01,  4.97916667e+00,
#         -8.71753472e+00,  6.59722222e-01,  1.44497222e-01,
#          2.91190410e-01,  9.81964540e-02,  1.93136111e-01,
#          5.56852778e-01,  1.12399396e+02,  2.41572813e+05,
#          3.92361111e+00],
#        [ 5.87728125e-01,  5.39312500e-01,  4.78125000e+00,
#         -1.06923438e+01,  5.62500000e-01,  1.43831250e-01,
#          4.62341875e-01,  1.79280501e-01,  2.55650000e-01,
#          4.88253125e-01,  1.05919219e+02,  3.81246719e+05,
#          3.96875000e+00],
#        [ 6.27489362e-01,  3.49658784e-01,  5.05775076e+00,
#         -1.30541246e+01,  6.62613982e-01,  9.04984802e-02,
#          6.38663891e-01,  5.52770796e-01,  1.59975988e-01,
#          3.78520973e-01,  1.15434748e+02,  1.59911502e+05,
#          3.83282675e+00],
#        [ 6.55673540e-01,  3.04212268e-01,  5.27491409e+00,
#         -1.41664158e+01,  5.36082474e-01,  1.04851546e-01,
#          6.61516495e-01,  7.17147981e-01,  1.54618557e-01,
#          3.65402062e-01,  1.10358041e+02,  1.26708567e+05,
#          3.92439863e+00],
#        [ 5.92733962e-01,  5.57707547e-01,  5.52830189e+00,
#         -9.96784906e+00,  6.22641509e-01,  1.64734906e-01,
#          3.49288953e-01,  1.10983585e-01,  2.18556604e-01,
#          5.00011321e-01,  1.10065453e+02,  2.81264575e+05,
#          3.93396226e+00],
#        [ 6.22954397e-01,  4.22377199e-01,  5.21498371e+00,
#         -1.15352215e+01,  6.35179153e-01,  8.71918567e-02,
#          5.73085476e-01,  3.60143481e-01,  1.75015309e-01,
#          4.82826384e-01,  1.15924101e+02,  1.80627866e+05,
#          3.90879479e+00],
#        [ 6.25511111e-01,  6.11976667e-01,  5.23333333e+00,
#         -8.48616111e+00,  6.33333333e-01,  1.50787222e-01,
#          2.96927944e-01,  1.03274722e-01,  2.05947778e-01,
#          5.15763889e-01,  1.12885456e+02,  2.26053472e+05,
#          3.93888889e+00],
#        [ 5.14300000e-01,  4.14000000e-01,  4.60000000e+00,
#         -1.34562000e+01,  7.00000000e-01,  6.87000000e-02,
#          6.08119000e-01,  3.52870000e-01,  2.99540000e-01,
#          3.64120000e-01,  1.04208600e+02,  5.04734100e+05,
#          3.90000000e+00],
#        [ 5.10500000e-01,  6.07500000e-01,  2.50000000e+00,
#         -9.55450000e+00,  5.00000000e-01,  4.92500000e-02,
#          2.81500000e-01,  2.79000000e-05,  5.06500000e-01,
#          4.16000000e-01,  9.88595000e+01,  6.25880000e+05,
#          4.00000000e+00],
#        [ 5.77700000e-01,  4.27140000e-01,  5.60000000e+00,
#         -1.16210000e+01,  4.66666667e-01,  1.08840000e-01,
#          6.48613333e-01,  2.40447510e-01,  1.78843333e-01,
#          4.27526667e-01,  1.09932500e+02,  4.11438700e+05,
#          3.66666667e+00],
#        [ 6.37784091e-01,  2.83176136e-01,  5.00000000e+00,
#         -1.45280682e+01,  5.79545455e-01,  1.35350000e-01,
#          6.74342273e-01,  6.88602652e-01,  1.38846591e-01,
#          4.75855682e-01,  1.11464727e+02,  7.29317841e+04,
#          3.95454545e+00],
#        [ 5.34666667e-01,  3.64333333e-01,  6.00000000e+00,
#         -1.51366667e+01,  6.66666667e-01,  1.50800000e-01,
#          6.89666667e-01,  3.04590267e-01,  1.53666667e-01,
#          2.56566667e-01,  1.08204333e+02,  6.98111000e+05,
#          3.00000000e+00],
#        [ 5.90276923e-01,  5.25138000e-01,  4.83076923e+00,
#         -1.06868923e+01,  6.15384615e-01,  1.69080000e-01,
#          3.98088462e-01,  1.33258676e-01,  2.58266154e-01,
#          4.38369231e-01,  1.15621477e+02,  3.23876846e+05,
#          3.89230769e+00],
#        [ 6.37787356e-01,  3.46303736e-01,  5.16666667e+00,
#         -1.31307644e+01,  6.17816092e-01,  8.26864943e-02,
#          6.45728305e-01,  6.27502060e-01,  1.63855460e-01,
#          3.78877586e-01,  1.12763655e+02,  1.52715989e+05,
#          3.89655172e+00],
#        [ 6.48968750e-01,  3.33769034e-01,  5.49431818e+00,
#         -1.34149062e+01,  5.59659091e-01,  8.97170455e-02,
#          6.42545455e-01,  6.74230378e-01,  1.53053409e-01,
#          3.82943182e-01,  1.11571855e+02,  1.38687509e+05,
#          3.94318182e+00],
#        [ 6.25675573e-01,  4.57675038e-01,  5.27862595e+00,
#         -1.11045534e+01,  6.33587786e-01,  8.81320611e-02,
#          5.08165267e-01,  2.81344339e-01,  1.60578244e-01,
#          4.82337405e-01,  1.15053676e+02,  1.88502347e+05,
#          3.91984733e+00],
#        [ 5.61312500e-01,  4.11743750e-01,  5.37500000e+00,
#         -1.17827500e+01,  5.00000000e-01,  5.97437500e-02,
#          7.35937500e-01,  3.17846351e-01,  1.71993750e-01,
#          5.20606250e-01,  1.10900625e+02,  4.75116688e+05,
#          3.75000000e+00],
#        [ 6.75275510e-01,  3.00135561e-01,  5.60714286e+00,
#         -1.40591939e+01,  5.76530612e-01,  1.09402551e-01,
#          6.38720893e-01,  7.51037719e-01,  1.52313265e-01,
#          4.02788776e-01,  1.08018102e+02,  1.06371714e+05,
#          3.93877551e+00],
#        [ 6.38644776e-01,  3.23929164e-01,  5.34328358e+00,
#         -1.34302955e+01,  5.85074627e-01,  9.18450746e-02,
#          6.75590627e-01,  6.72465905e-01,  1.58782388e-01,
#          3.78817612e-01,  1.09484654e+02,  1.32545006e+05,
#          3.90149254e+00],
#        [ 5.63363636e-01,  4.79345455e-01,  3.72727273e+00,
#         -1.03722727e+01,  3.63636364e-01,  1.09200000e-01,
#          5.62272727e-01,  2.86729373e-01,  2.48881818e-01,
#          3.97818182e-01,  1.09150364e+02,  5.42219091e+05,
#          3.81818182e+00],
#        [ 5.43117647e-01,  4.44067647e-01,  5.32352941e+00,
#         -1.15542941e+01,  5.88235294e-01,  1.55879412e-01,
#          5.87466765e-01,  1.97472264e-01,  2.56952941e-01,
#          3.55758824e-01,  1.08736853e+02,  3.62269412e+05,
#          3.91176471e+00],
#        [ 6.19400000e-01,  5.92176667e-01,  5.50833333e+00,
#         -9.02920000e+00,  5.66666667e-01,  1.75157500e-01,
#          3.14675200e-01,  1.57817259e-01,  2.03091667e-01,
#          4.71827500e-01,  1.04063267e+02,  2.49822533e+05,
#          3.92500000e+00],
#        [ 6.08275862e-01,  5.66855172e-01,  5.49425287e+00,
#         -9.10294253e+00,  5.86206897e-01,  1.95165517e-01,
#          3.11814460e-01,  8.25935779e-02,  2.24714943e-01,
#          4.80760920e-01,  1.11681345e+02,  2.93675471e+05,
#          3.97701149e+00],
#        [ 6.38080139e-01,  3.67472125e-01,  5.26480836e+00,
#         -1.25147979e+01,  6.75958188e-01,  8.42219512e-02,
#          6.03285805e-01,  5.22333453e-01,  1.54144251e-01,
#          3.88539373e-01,  1.12064080e+02,  1.66661136e+05,
#          3.90940767e+00],
#        [ 6.70153846e-01,  3.27202564e-01,  5.50427350e+00,
#         -1.38251282e+01,  5.12820513e-01,  1.34576068e-01,
#          6.13941197e-01,  7.13361131e-01,  1.59560684e-01,
#          4.44079487e-01,  1.13124051e+02,  8.78065983e+04,
#          3.91452991e+00],
#        [ 6.50931304e-01,  5.92517391e-01,  5.34782609e+00,
#         -9.01893913e+00,  6.00000000e-01,  1.62206957e-01,
#          3.44060078e-01,  1.23147343e-01,  1.96591304e-01,
#          5.10857391e-01,  1.06907539e+02,  2.67783991e+05,
#          3.93043478e+00],
#        [ 6.63460714e-01,  3.00352250e-01,  5.71071429e+00,
#         -1.36329786e+01,  5.14285714e-01,  9.22432143e-02,
#          6.86401000e-01,  7.43589487e-01,  1.45978929e-01,
#          3.72653214e-01,  1.04760725e+02,  1.20832168e+05,
#          3.92142857e+00],
#        [ 6.21908425e-01,  4.84175092e-01,  5.20512821e+00,
#         -1.05977399e+01,  6.81318681e-01,  1.01509158e-01,
#          4.84125912e-01,  2.55705305e-01,  1.87867766e-01,
#          5.04604396e-01,  1.12248487e+02,  1.95976209e+05,
#          3.93406593e+00],
#        [ 6.45885135e-01,  6.18110135e-01,  5.45270270e+00,
#         -8.11847973e+00,  6.01351351e-01,  1.57444595e-01,
#          2.58328703e-01,  6.70638741e-02,  1.81893919e-01,
#          5.48459459e-01,  1.12961020e+02,  2.33528297e+05,
#          4.00000000e+00],
#        [ 6.26393443e-01,  5.72751366e-01,  5.59562842e+00,
#         -8.98001639e+00,  6.55737705e-01,  1.16693443e-01,
#          3.80569951e-01,  1.74664099e-01,  2.12744809e-01,
#          5.17713115e-01,  1.13295891e+02,  2.18577667e+05,
#          3.93442623e+00]])

# %%
cluster1.labels_
# Out:
# array([24, 34, 10, ...,  0, 42, 40], dtype=int32)

# %%
big_df1_clean_c = big_df1_clean.copy()
big_df1_clean_c['cluster1'] = cluster1.labels_
big_df1_clean_c.head()
# Out:
#                                     danceability  energy  key  loudness  mode  \
# Sing About Me, I'm Dying Of Thirst         0.654   0.753   11    -7.556     0
# Yonkers                                    0.712   0.759   11    -5.397     1
# Angel Duster                               0.507   0.810    6    -6.840     1
# Rhymes Like Dimes                          0.644   0.751    0    -5.652     1
# The Last to Say                            0.684   0.397    2   -10.319     1
#
#                                     speechiness  acousticness  \
# Sing About Me, I'm Dying Of Thirst       0.3950         0.303
# Yonkers                                  0.3340         0.016
# Angel Duster                             0.1050         0.003
# Rhymes Like Dimes                        0.2680         0.662
# The Last to Say                          0.0809         0.210
#
#                                     instrumentalness  liveness  valence  \
# Sing About Me, I'm Dying Of Thirst          0.000081     0.130   0.3710
# Yonkers                                     0.080800     0.217   0.7380
# Angel Duster                                0.000008     0.314   0.2070
# Rhymes Like Dimes                           0.000000     0.170   0.7590
# The Last to Say                             0.000000     0.235   0.0542
#
#                                       tempo  duration_ms  time_signature  \
# Sing About Me, I'm Dying Of Thirst  110.722       723573               5
# Yonkers                              79.103       249333               4
# Angel Duster                        175.710       309840               5
# Rhymes Like Dimes                    99.948       258613               4
# The Last to Say                      83.027       256348               4
#
#                                     cluster1
# Sing About Me, I'm Dying Of Thirst        24
# Yonkers                                   34
# Angel Duster                              10
# Rhymes Like Dimes                          1
# The Last to Say                            1

# %%
big_df1_clean_c["cluster1"].value_counts()
# Out:
# 6     359
# 27    352
# 26    347
# 31    335
# 0     333
# 15    327
# 18    308
# 16    291
# 36    288
# 39    280
# 40    274
# 28    261
# 11    256
# 2     236
# 5     217
# 30    196
# 42    183
# 19    180
# 9     158
# 41    148
# 13    144
# 1     134
# 34    120
# 37    117
# 38    115
# 17    106
# 23     88
# 35     87
# 10     74
# 25     65
# 4      49
# 33     34
# 14     32
# 22     30
# 8      29
# 3      21
# 29     16
# 32     11
# 20     10
# 7       6
# 24      3
# 21      2
# 12      2
# Name: cluster1, dtype: int64

# %%
plt.scatter(big_df1_clean_c.iloc[:,0], big_df1_clean_c.iloc[:,10], c = big_df1_clean_c.iloc[:,-1]);

# %%
markersize= big_df1_clean_c['tempo']
markercolour= big_df1_clean_c['cluster1']

fig1=go.Scatter3d(x=big_df1_clean_c['danceability'],
                  y=big_df1_clean_c['energy'],
                  z=big_df1_clean_c['acousticness'],
                 marker=dict (size=markersize,
                              color=markercolour,
                              opacity=0.9,
                              colorscale='Reds'),
                 line=dict (width=0.2),
                 mode='markers')
#make layout 
mylayout=go.Layout(scene=dict(xaxis=dict(title="danceability"),
                              yaxis=dict(title='energy'),
                              zaxis=dict(title='acousticness')))

# %%
plotly.offline.plot({"data":[fig1],
                    "layout":mylayout},
                   auto_open=True,
                   filename=("5Dplot.html"))
# Out:
# '5Dplot.html'

# %% [markdown]
# # Cluster 2 - Scaled data

# %%
kmeans4 = KMeans(n_clusters = 43)

# %%
cluster4 = kmeans4.fit(big_df1_clean_scaled)

# %%
cluster4.cluster_centers_
# Out:
# array([[ 3.16072028e-01,  5.18808840e-02, -3.20968371e-01,
#          8.00308686e-02,  7.32255511e-01, -2.10796213e-01,
#         -5.09700426e-01,  8.69917447e-01, -2.64434931e-01,
#          5.74150410e-01,  1.48834639e+00, -6.84805464e-01,
#          1.26864403e-01],
#        [-1.02434763e-01,  3.92490340e-02,  8.75089846e-01,
#          7.81522074e-02,  8.11472570e-01, -5.34798751e-01,
#          1.63573738e-01, -9.89632922e-01, -2.34037518e-01,
#          1.03304678e+00,  6.98359076e-02, -2.45616998e-01,
#          1.63788276e-01],
#        [-1.67271111e+00, -9.67345956e-01, -1.84802603e-01,
#         -8.01136800e-01, -1.23232755e+00, -5.17310592e-01,
#          9.27260191e-01, -5.28050801e-01, -8.28580993e-02,
#         -8.02964210e-01, -6.57921447e-01,  6.79843212e-01,
#         -9.77031648e-02],
#        [ 5.14186438e-02, -3.26479917e-01,  2.59042226e-01,
#         -1.35112245e-01, -1.23232755e+00, -2.95746924e-01,
#          4.76749235e-01,  9.09589831e-01, -2.25538900e-01,
#         -3.33400812e-01,  1.37153065e+00, -5.83663585e-01,
#          2.27104032e-01],
#        [ 2.44707132e-01, -7.93986139e-01, -1.10560952e+00,
#         -7.55834587e-01,  8.11472570e-01, -3.94262664e-01,
#          7.67601989e-01,  1.00773240e+00, -3.39117322e-01,
#         -7.89749027e-01,  9.03686115e-01, -5.60889059e-01,
#          1.06841286e-01],
#        [ 9.60816279e-01,  1.16154021e+00, -6.62309428e-01,
#          1.07577810e+00, -1.23232755e+00,  1.09518586e-01,
#         -1.10566628e+00, -9.94546838e-01, -1.24352008e-01,
#          5.18118257e-01, -3.45333310e-01,  3.48909786e-01,
#          2.13774968e-01],
#        [ 6.49273055e-01, -8.27022281e-02, -8.77960638e-01,
#          1.34515813e-01, -1.23232755e+00, -1.08750458e-01,
#          3.49508362e-01,  7.48631888e-01,  4.60456814e-03,
#          4.81207886e-01, -5.81966956e-01, -6.04202034e-01,
#          1.28497621e-01],
#        [ 6.69068424e-01, -2.27055949e-01,  6.50604279e-01,
#         -5.46169130e-02,  8.11472570e-01, -2.57639076e-01,
#          6.99744833e-01,  9.05322369e-01, -3.08324208e-01,
#          4.80445325e-01, -4.86251741e-01, -5.57168103e-01,
#          1.84594699e-01],
#        [-7.56844356e-01, -5.41636373e-01,  7.64093735e-03,
#         -5.31373790e-01, -1.30053326e-01, -2.85635181e-02,
#          4.41494720e-01,  4.02063090e-01,  4.95302812e-02,
#         -5.04535467e-01, -6.96530035e-02, -4.25887191e-02,
#         -6.77992561e+00],
#        [-3.52875822e-02,  1.20994607e+00, -7.76909508e-02,
#          7.99853685e-01,  7.80968091e-01, -5.15018511e-01,
#         -1.02435494e+00, -9.84259141e-01,  1.46055879e+00,
#          1.21484184e+00,  1.85602439e-01,  2.96904854e-01,
#          1.98726024e-01],
#        [ 3.67609990e-01,  1.18522530e+00,  7.34119844e-01,
#          9.17302452e-01,  8.11472570e-01,  1.78117121e+00,
#         -9.78420529e-01, -1.02533371e+00,  6.72348485e-02,
#          5.86023237e-01, -6.11736804e-01,  8.05871989e-01,
#          2.13393982e-01],
#        [-1.62519434e+00, -8.73655775e-01,  1.08812692e-01,
#         -1.05372795e+00, -2.36630053e-01, -3.64585316e-01,
#          8.40626056e-01,  6.14478145e-01, -2.97526677e-01,
#         -9.65837118e-01,  1.53260962e+00, -1.92066579e-01,
#         -2.11881127e+00],
#        [-9.36972924e-01,  1.29273170e+00, -6.60186903e-02,
#          8.93928806e-01, -2.10427488e-01,  2.10930963e+00,
#         -9.07592740e-01, -9.05449723e-01,  3.01913460e+00,
#          5.60613922e-01,  1.40822757e+00,  5.27341859e-01,
#          1.48344779e-01],
#        [-7.78491951e-01, -5.73875333e-01, -1.20719588e-01,
#         -9.49749228e-02,  6.19866309e-01, -5.90712119e-01,
#          5.15519466e-01, -6.48875203e-01, -4.90100738e-02,
#         -3.81017448e-01, -2.20295413e-01,  1.05078301e-01,
#         -2.11881127e+00],
#        [ 1.47955489e-01, -8.08929851e-01,  8.14333370e-01,
#         -8.75194837e-01,  8.11472570e-01, -4.26242446e-01,
#          7.16943428e-01,  1.00055975e+00, -2.95419254e-01,
#         -9.16667500e-01,  8.80049516e-01, -4.59038962e-01,
#          1.89565798e-01],
#        [ 2.88717576e-01,  1.15313333e+00,  2.27287316e-01,
#          9.19436242e-01, -1.23232755e+00,  2.12160675e+00,
#         -8.77646500e-01, -9.90452218e-01, -2.39777377e-01,
#          4.42358443e-01, -5.44372471e-01,  7.98699562e-01,
#          2.29421882e-01],
#        [ 6.83117960e-02, -6.66922211e-01, -1.08692027e+00,
#         -4.10622626e-01,  8.11472570e-01, -3.83039320e-01,
#          7.73691393e-01,  9.02048610e-01, -2.42831990e-01,
#         -7.48597611e-01, -8.93528538e-01, -5.28936222e-01,
#          1.39301991e-01],
#        [-1.57669595e+00, -1.51854970e-01,  2.32316604e-01,
#          2.73113213e-02,  7.02759798e-01, -4.43653621e-01,
#          3.28949883e-01, -5.58318522e-01,  1.10083165e-01,
#          8.06444977e-02,  1.70429209e+00,  1.13102303e-01,
#          1.74071372e-01],
#        [-6.65816866e-01, -1.19858417e-01, -4.97261600e-02,
#         -1.50448334e-01, -2.10427488e-01, -3.91247801e-01,
#          4.20100278e-01, -2.06279104e-01, -5.55920150e-02,
#         -4.96194678e-03,  8.25502451e-02,  3.93616356e+00,
#          4.85152735e-02],
#        [ 9.46224830e-01,  1.21651759e+00,  1.20110268e+00,
#          1.14007533e+00, -1.23232755e+00,  2.26627500e-01,
#         -1.03978807e+00, -9.99060471e-01, -1.88329786e-01,
#          6.86129351e-01, -3.43739527e-01,  7.12576963e-01,
#          1.84420238e-01],
#        [-6.26026597e-01,  4.73131364e-01, -4.57039416e-01,
#          6.71854028e-01,  6.67073649e-01, -5.06712501e-01,
#         -9.16162148e-01, -8.88952582e-01, -2.29477349e-01,
#         -5.53138204e-01, -2.85645350e-01,  7.77134497e-01,
#          1.86130713e-01],
#        [ 6.62937852e-01, -4.07561940e-01,  1.00745266e+00,
#         -1.58975190e-01, -1.23232755e+00, -6.04848570e-02,
#          4.98249070e-01,  7.92696923e-01, -2.99699399e-01,
#          5.93062974e-02, -7.11275275e-01, -7.26654413e-01,
#          1.15585673e-01],
#        [ 6.50415147e-01,  1.25382060e+00,  7.85755574e-01,
#          1.09102391e+00,  8.11472570e-01, -2.67805916e-01,
#         -1.06424702e+00, -1.00687353e+00, -2.76930171e-01,
#          7.72079641e-01, -3.22858760e-02,  4.67497457e-01,
#          1.65300005e-01],
#        [-6.04629765e-01, -8.10987743e-01,  7.49609593e-01,
#         -7.07478003e-01, -1.23232755e+00, -3.82302459e-01,
#          7.81344434e-01,  9.17560808e-01, -2.49428691e-01,
#         -9.97462070e-01, -9.61247541e-01, -4.54105003e-01,
#          2.36307710e-01],
#        [-4.64125870e-01,  1.29056091e+00, -1.60125564e-02,
#          9.49855225e-01,  8.11472570e-01, -3.60167426e-01,
#         -9.96302702e-01, -1.00913863e+00, -2.18505988e-01,
#          1.06140917e+00,  1.67763697e+00,  2.29550544e-01,
#          1.69203256e-01],
#        [-1.57077098e+00, -1.20935865e+00, -5.12113987e-01,
#         -1.84242791e+00,  7.67676853e-01, -5.59614357e-01,
#          1.07317395e+00,  1.02195941e+00, -4.09893107e-01,
#         -1.01993538e+00, -4.52229168e-01, -1.77701589e-01,
#          1.82172186e-01],
#        [-5.32266115e-01, -4.13373909e-01, -1.44345029e-01,
#         -4.48482116e-01, -1.28675483e-01, -3.46170402e-01,
#          4.34575416e-01,  3.53351110e-01,  3.49687147e+00,
#         -3.98625442e-01, -1.44039768e-01, -1.84729344e-01,
#         -9.85233246e-03],
#        [ 5.06292112e-01,  1.13698230e+00, -1.17000733e+00,
#          9.26117591e-01,  8.11472570e-01,  1.65445085e+00,
#         -1.05960732e+00, -9.96216699e-01,  2.05474863e-01,
#          3.94135048e-01, -4.70301430e-01,  7.44612027e-01,
#          2.79196069e-01],
#        [ 5.06577614e-02, -4.37021170e-01, -8.58152056e-01,
#         -2.66966761e-01,  8.11472570e-01, -4.89001813e-01,
#          4.92017844e-01, -9.07110467e-01, -1.32249435e-01,
#          6.93002190e-01,  1.72444892e-02,  1.37088142e-02,
#          2.09072173e-01],
#        [-1.58587335e-01,  1.31533711e+00, -1.62144619e-01,
#          9.40983768e-01,  1.66614140e-02,  9.71002831e-01,
#         -1.01673550e+00, -9.72643523e-01,  4.13747211e+00,
#          4.75772354e-01, -4.02594079e-01,  1.33842163e+00,
#          1.72975610e-01],
#        [-3.61171710e-01, -1.18152010e+00,  3.15877161e-01,
#         -1.91261649e+00, -1.21905612e+00, -5.10020164e-01,
#          9.53491860e-01,  1.00378073e+00, -2.82505382e-01,
#         -9.43194747e-01,  3.17323237e-01, -6.30683273e-01,
#          1.98726024e-01],
#        [ 5.10950933e-01, -5.95353421e-03,  4.52603447e-01,
#          2.07318076e-01, -1.23232755e+00, -2.36408657e-01,
#         -1.01670698e+00,  7.42246837e-01, -1.22004970e-01,
#         -2.68308905e-01, -6.08807365e-01, -4.55189564e-01,
#          1.58768485e-01],
#        [-5.19206864e-01,  1.20017701e+00,  1.04602689e-01,
#          9.84201961e-01, -2.64211701e-01,  2.12222099e+00,
#         -1.02165410e+00, -1.02264535e+00,  2.55107132e-03,
#          2.28160324e-01,  1.78845977e+00,  8.45502021e-01,
#          1.49935765e-01],
#        [-2.26642950e-01, -3.01176803e-01, -1.18353708e-01,
#         -4.86994815e-02, -1.23232755e+00, -3.16887659e-01,
#          4.18699625e-01, -8.79604019e-01, -1.79325622e-01,
#          7.84720797e-01,  3.72856682e-01,  3.23182043e-02,
#          9.09335918e-02],
#        [-1.46598754e+00, -1.13124826e+00,  1.09533323e-01,
#         -9.11174179e-01,  8.11472570e-01, -6.09074598e-01,
#          9.72462894e-01, -9.05516082e-01, -1.21880774e-01,
#         -7.94775444e-01, -5.03464320e-01,  6.10205060e-01,
#          3.36061568e-01],
#        [-1.09335440e-01, -8.56505968e-01,  8.07364926e-01,
#         -7.76371558e-01,  8.11472570e-01, -3.87159613e-01,
#          7.03995726e-01,  9.42816330e-01, -3.16526138e-01,
#         -8.70828608e-01, -8.86979877e-01, -4.92973117e-01,
#          1.24762068e-01],
#        [ 3.76572891e-01, -3.36651304e-01, -2.18006878e-01,
#         -2.43234409e-02, -3.49204039e-01,  2.46208732e+00,
#          2.43943299e-02,  5.56324568e-01, -2.04077652e-01,
#          2.92019981e-01,  1.52126721e+00, -7.39498066e-01,
#          1.41502881e-01],
#        [ 5.10982497e-01, -5.34935066e-01,  1.54366875e-01,
#         -3.55581876e-01, -1.92179272e-01,  2.72712745e+00,
#          5.28017827e-01,  3.08521292e-01, -1.90483319e-01,
#          1.94384208e-01, -8.64256369e-01, -7.79520925e-01,
#          7.45722404e-02],
#        [ 7.55836139e-01,  1.52128270e-02, -4.28018347e-01,
#          2.39149764e-01,  8.11472570e-01, -1.67388558e-01,
#         -8.76338920e-01,  7.36149940e-01, -1.31665863e-01,
#         -1.01913437e-01, -7.06963213e-01, -6.59164946e-01,
#          1.86130713e-01],
#        [ 1.25799901e-01,  1.16908653e+00,  8.58662792e-02,
#          1.02824235e+00, -1.23232755e+00, -4.51741923e-02,
#         -1.07633211e+00, -6.70601289e-01, -7.93170065e-02,
#          9.43205595e-01,  1.63586389e+00,  1.64218873e-01,
#          1.78396750e-01],
#        [ 7.46471923e-01,  1.09172827e+00, -1.00754435e+00,
#          8.86336606e-01,  8.11472570e-01, -3.84296946e-01,
#         -9.30175063e-01, -9.92192522e-01, -3.74978587e-01,
#          1.26531413e+00, -5.02641434e-02,  1.92813563e-01,
#          1.98726024e-01],
#        [ 1.68934985e-01, -7.55349252e-01, -9.83486683e-01,
#         -6.07280172e-01, -1.23232755e+00, -4.19722641e-01,
#          7.07107219e-01,  9.59085252e-01, -3.53432133e-01,
#         -9.11346937e-01, -6.01338509e-01, -4.96768652e-01,
#          7.06209475e-02],
#        [ 3.11900358e-01,  1.24373797e+00,  5.90112576e-01,
#          9.40188048e-01, -1.14804713e+00,  1.50290125e+00,
#         -9.09905351e-01, -1.01104542e+00,  1.70939180e+00,
#          5.49437736e-01, -5.61710214e-01,  1.12908951e+00,
#          1.50941750e-01]])

# %%
cluster4.labels_
# Out:
# array([18, 10, 24, ...,  5, 22, 20], dtype=int32)

# %%
big_df1_clean_scaled_c = big_df1_clean_scaled_df.copy()
big_df1_clean_scaled_c["cluster"] = cluster4.labels_
big_df1_clean_scaled_c.head()
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      0.127996  1.363510  1.589710  0.820433 -1.232328     2.535376
# 1      0.542850  1.388238  1.589710  1.237792  0.811473     1.992466
# 2     -0.923445  1.598424  0.184479  0.958844  0.811473    -0.045674
# 3      0.056469  1.355268 -1.501798  1.188497  0.811473     1.405054
# 4      0.342576 -0.103671 -0.939706  0.286314  0.811473    -0.260168
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.708953         -1.062171 -0.318547 -0.273133 -0.025540     7.742411
# 1     -1.568099         -0.869582  0.312352  1.140534 -0.964810     0.973275
# 2     -1.607015         -1.062345  1.015769 -0.904853  1.904985     1.836931
# 3      0.365728         -1.062364 -0.028479  1.221425 -0.345591     1.105734
# 4     -0.987352         -1.062364  0.442883 -1.493431 -0.848244     1.073404
#
#    time_signature  cluster
# 0        2.516263       18
# 1        0.198726       10
# 2        2.516263       24
# 3        0.198726       27
# 4        0.198726       20

# %%
big_df1_clean_scaled_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6624 entries, 0 to 6623
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      6624 non-null   float64
#  1   energy            6624 non-null   float64
#  2   key               6624 non-null   float64
#  3   loudness          6624 non-null   float64
#  4   mode              6624 non-null   float64
#  5   speechiness       6624 non-null   float64
#  6   acousticness      6624 non-null   float64
#  7   instrumentalness  6624 non-null   float64
#  8   liveness          6624 non-null   float64
#  9   valence           6624 non-null   float64
#  10  tempo             6624 non-null   float64
#  11  duration_ms       6624 non-null   float64
#  12  time_signature    6624 non-null   float64
#  13  cluster           6624 non-null   int32
# dtypes: float64(13), int32(1)
# memory usage: 698.8 KB

# %% [raw]
# markersize= big_df1_clean_scaled_c['cluster']
# markercolour= big_df1_clean_scaled_c['cluster']
#
# fig2=go.Scatter3d(x=big_df1_clean_scaled_c['danceability'],
#                   y=big_df1_clean_scaled_c['energy'],
#                   z=big_df1_clean_scaled_c['acousticness'],
#                  marker=dict (size=markersize,
#                               color=markercolour,
#                               opacity=0.9,
#                               colorscale='Reds'),
#                  line=dict (width=0.2),
#                  mode='markers')
# #make layout
# mylayout2=go.Layout(scene=dict(xaxis=dict(title="danceability"),
#                               yaxis=dict(title='energy'),
#                               zaxis=dict(title='acousticness')))

# %% [markdown]
# plotly.offline.plot({"data":[fig2],
#                     "layout":mylayout2},
#                    auto_open=True,
#                    filename=("5Dplot.html"))

# %% [markdown]
# # Create final dataframe

# %%
cluster_column = big_df1_clean_scaled_c["cluster"].to_list()

# %%
songname_column = big_df1["song_name"].to_list()

# %%
artist_column = big_df1["song_artist"].to_list()

# %%
songid_column = big_df1["song_ID"].to_list()

# %%
final_df=pd.DataFrame({"song_name":songname_column, "song_ID":songid_column, "artist":artist_column, "cluster":cluster_column})

# %%
final_df
# Out:
#                                song_name                 song_ID  \
# 0     Sing About Me, I'm Dying Of Thirst  1Z2FvDFZSDQ23s4BDqpWqZ
# 1                                Yonkers  4OKXvqtfwlvY2fYJ2lzHPH
# 2                           Angel Duster  0VLYOGNIaiOxEHKWOctcA4
# 3                      Rhymes Like Dimes  12OkZyDWNBLUqoReoseGrc
# 4                        The Last to Say  4O7P2Rug3l4IySk0TEx4Xe
# ...                                  ...                     ...
# 6619   Moth To A Flame (with The Weeknd)  2gpWyfu7eZ01zzncHpxOtA
# 6620                      'Til You Can't  13rC4iKtfQocWIfzPOJxaT
# 6621                               Woman  6Uj1ctrBOjOas8xZXGqKk4
# 6622                      Take My Breath  6OGogr19zPTM4BALXuMQpF
# 6623                         For Tonight  61Emqg95O9zo1GNOcyxq4Y
#
#                    artist  cluster
# 0          Kendrick Lamar       18
# 1      Tyler, The Creator       10
# 2          Run The Jewels       24
# 3                 MF DOOM       27
# 4              Atmosphere       20
# ...                   ...      ...
# 6619  Swedish House Mafia       20
# 6620         Cody Johnson       24
# 6621             Doja Cat        5
# 6622           The Weeknd       22
# 6623               Giveon       20
#
# [6624 rows x 4 columns]

# %%
final_df.loc[final_df['song_name'] == "goodnight"]
# Out:
#       song_name                 song_ID artist  cluster
# 4539  goodnight  7o6pBUyCm2rdHeeJ66W39i  L.Dre        6

# %% [markdown]
# # Creating the displayer of the suggested song

# %%
from IPython.core.display import display
from IPython.display import IFrame

def recommend(track_id):
	display(IFrame(src=f"https://open.spotify.com/embed/track/{track_id}",
               width="320",
               height="80",
               frameborder="0",
               allowtransparency="true",
               allow="encrypted-media",
              ))

# %% [markdown]
# # Creating recomender:

# %%
from unidecode import unidecode

# %%
for song, artist in final_df.iterrows( ):
    hs = input("""Please type your favourite song or artist of the moment:
    
""")
    hs2 = unidecode(hs.lower().replace(" ",""))
    check = final_df[final_df['song_name'].str.lower().str.replace(" ","").apply(unidecode).str.contains(hs2)] + final_df[final_df['artist'].str.lower().str.replace(" ","").apply(unidecode).str.contains(hs2)]
    suggestion1 = top_100.sample().index.tolist()
    check2 = top_100[top_100['song_name'].str.lower().str.replace(" ","").apply(unidecode).str.contains(hs2)] + top_100[top_100['song_artist'].str.lower().str.replace(" ","").apply(unidecode).str.contains(hs2)]
    index = check.index.tolist()
    if len(check) != 0 or len(check2) != 0:
        answer = input("""
Do you mean """ + final_df.song_name[index].values[0] + """ by """ + final_df.artist[index].values[0] + """?
[y/n]
         
""")
        if answer.lower() == 'y':
            song_cluster = final_df.loc[index, 'cluster'].iloc[0]
            
            if len(check2) != 0:
                
                print("""
Good choice! Your song was one of the Top 100 hot songs in Spain last week!
We think you could enjoy """ + top_100['song_name'][suggestion1].item() + """ by """ + top_100['song_artist'][suggestion1].item() + """.""")
                recommend(top_100['song_ID'][suggestion1].item())
                break
            else:
                final_df_mask = final_df['cluster']== song_cluster
                final_df_filtered = final_df[final_df_mask]
                suggestion2 = final_df_filtered.sample().index.tolist()

                print("""
Interesting choice!
Your song wasn't one of the Top 100 hot songs in Spain last week but it is in our database.
Why don't you try """ + final_df['song_name'][suggestion2].item() + """ by """ + final_df['artist'][suggestion2].item() + """?""")
                recommend(final_df['song_ID'][suggestion2].item())
                break
        else:
            print("""
We're sorry it wasn't the song you expected. Could you type it again trying to be more specific?
            
            """)
            continue
    else:
        results_test= sp.search(q = hs, limit = 1)

        song_name_searched=[]
        song_ID_searched=[]
        song_artist_searched=[]
        playlist=results_test

        for r in results_test: 
            song_ID_searched.append(results_test["tracks"]["items"][0]["id"])
        for r in results_test: 
            song_name_searched.append(results_test["tracks"]["items"][0]["name"])
        for r in results_test:
            song_artist_searched.append(results_test["tracks"]["items"][0]["artists"][0]["name"])

        song_id_searched_df = pd.DataFrame({"song_name":song_name_searched,"song_ID":song_ID_searched,"song_artist":song_artist_searched})

        feats=sp.audio_features(tracks=song_ID_searched)
        audio_feat_df=pd.DataFrame(feats)
        song_input = pd.concat([song_id_searched_df, audio_feat_df], axis=1)
        song_input_drop = song_input.drop(['song_ID',
         'song_artist',
         'type',
         'id',
         'uri',
         'track_href',
         'analysis_url'], axis = 1)
        song_input_drop.index = song_input_drop.iloc[:,0]
        song_input_drop_clean = song_input_drop.iloc[:,1:]
        song_input_drop_clean.rename_axis(None, inplace = True)
        
        
        new=kmeans1.predict(song_input_drop_clean)
        song_input["cluster"] = new
        song_name_searched2 = song_input.index.tolist()
        song_name_searched2
        pred = song_input.loc[song_name_searched2, 'cluster'].iloc[0]
        final_df_mask2 = final_df['cluster']== pred
        final_df_filtered2 = final_df[final_df_mask2]
        suggestion3 = final_df_filtered2.sample().index.tolist()
        answer = input("""
Do you mean """ + song_input.song_name[song_name_searched2].values[0] + """ by """ + song_input.song_artist[song_name_searched2].values[0] + """?
[y/n]
         
""")
        if answer.lower() == 'y':
            
            print("""
Wow, we weren't expecting that choice!
Unfortunatelly, we don't have that song or artist in our database, but based on the features of the song
we can recomend you """ +  final_df['song_name'][suggestion3].item() + """ by """ + final_df['artist'][suggestion3].item() + """.""")
            recommend(final_df['song_ID'][suggestion3].item())
            break
        else:
            print("""
We're sorry it wasn't the song you expected. Could you type it again trying to be more specific?
            
            """)
            continue
# Out:
# Please type your favourite song or artist of the moment:
#
# AMARIGLO
#
# Do you mean Amarillo by J Balvin?
# [y/n]
#
# asdfg
#
# We're sorry it wasn't the song you expected. Could you type it again trying to be more specific?
#
#
# Please type your favourite song or artist of the moment:
#
# asdfgh
#
# Do you mean Payloon Asdghigner / Twinkle Twinkle Little Star by Taline?
# [y/n]
#
# aamriglo
#
# We're sorry it wasn't the song you expected. Could you type it again trying to be more specific?
#
#
# Please type your favourite song or artist of the moment:
#
# amariglo
#
# Do you mean Amarillo by J Balvin?
# [y/n]
#
# y
#
# Wow, we weren't expecting that choice!
# Unfortunatelly, we don't have that song or artist in our database, but based on the features of the song
# we can recomend you Soul Food by Goodie Mob.
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0oipDSP2WW7wf5NeEjVxgK?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
